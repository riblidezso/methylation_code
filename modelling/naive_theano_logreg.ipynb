# %% [markdown]
# # Testing the theano logistic regression tutorial on the naive feature vector data
#
# - http://www.deeplearning.net/tutorial/logreg.html#logreg
#
#
# ### Modifications
#
# Changed data loader, and some small size related details in the code.
#
#
# ### Conclusions
#
# It runs ok, results are not very good of course.
#
#
# ---

# %%
import cPickle
import gzip
import os
import sys
import timeit

import numpy

import theano
import theano.tensor as T
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# #### Source from tutorial

# %%
class LogisticRegression(object):
    """Multi-class Logistic Regression Class

    The logistic regression is fully described by a weight matrix :math:`W`
    and bias vector :math:`b`. Classification is done by projecting data
    points onto a set of hyperplanes, the distance to which is used to
    determine a class membership probability.
    """

    def __init__(self, input, n_in, n_out):
        """ Initialize the parameters of the logistic regression

        :type input: theano.tensor.TensorType
        :param input: symbolic variable that describes the input of the
                      architecture (one minibatch)

        :type n_in: int
        :param n_in: number of input units, the dimension of the space in
                     which the datapoints lie

        :type n_out: int
        :param n_out: number of output units, the dimension of the space in
                      which the labels lie

        """
        # start-snippet-1
        # initialize with 0 the weights W as a matrix of shape (n_in, n_out)
        self.W = theano.shared(
            value=numpy.zeros(
                (n_in, n_out),
                dtype=theano.config.floatX
            ),
            name='W',
            borrow=True
        )
        # initialize the biases b as a vector of n_out 0s
        self.b = theano.shared(
            value=numpy.zeros(
                (n_out,),
                dtype=theano.config.floatX
            ),
            name='b',
            borrow=True
        )

        # symbolic expression for computing the matrix of class-membership
        # probabilities
        # Where:
        # W is a matrix where column-k represent the separation hyperplane for
        # class-k
        # x is a matrix where row-j  represents input training sample-j
        # b is a vector where element-k represent the free parameter of
        # hyperplane-k
        self.p_y_given_x = T.nnet.softmax(T.dot(input, self.W) + self.b)

        # symbolic description of how to compute prediction as class whose
        # probability is maximal
        self.y_pred = T.argmax(self.p_y_given_x, axis=1)
        # end-snippet-1

        # parameters of the model
        self.params = [self.W, self.b]

        # keep track of model input
        self.input = input

    def negative_log_likelihood(self, y):
        """Return the mean of the negative log-likelihood of the prediction
        of this model under a given target distribution.

        .. math::

            \frac{1}{|\mathcal{D}|} \mathcal{L} (\theta=\{W,b\}, \mathcal{D}) =
            \frac{1}{|\mathcal{D}|} \sum_{i=0}^{|\mathcal{D}|}
                \log(P(Y=y^{(i)}|x^{(i)}, W,b)) \\
            \ell (\theta=\{W,b\}, \mathcal{D})

        :type y: theano.tensor.TensorType
        :param y: corresponds to a vector that gives for each example the
                  correct label

        Note: we use the mean instead of the sum so that
              the learning rate is less dependent on the batch size
        """
        # start-snippet-2
        # y.shape[0] is (symbolically) the number of rows in y, i.e.,
        # number of examples (call it n) in the minibatch
        # T.arange(y.shape[0]) is a symbolic vector which will contain
        # [0,1,2,... n-1] T.log(self.p_y_given_x) is a matrix of
        # Log-Probabilities (call it LP) with one row per example and
        # one column per class LP[T.arange(y.shape[0]),y] is a vector
        # v containing [LP[0,y[0]], LP[1,y[1]], LP[2,y[2]], ...,
        # LP[n-1,y[n-1]]] and T.mean(LP[T.arange(y.shape[0]),y]) is
        # the mean (across minibatch examples) of the elements in v,
        # i.e., the mean log-likelihood across the minibatch.
        return -T.mean(T.log(self.p_y_given_x)[T.arange(y.shape[0]), y])
        # end-snippet-2

    def errors(self, y):
        """Return a float representing the number of errors in the minibatch
        over the total number of examples of the minibatch ; zero one
        loss over the size of the minibatch

        :type y: theano.tensor.TensorType
        :param y: corresponds to a vector that gives for each example the
                  correct label
        """

        # check if y has same dimension of y_pred
        if y.ndim != self.y_pred.ndim:
            raise TypeError(
                'y should have the same shape as self.y_pred',
                ('y', y.type, 'y_pred', self.y_pred.type)
            )
        # check if y is of the correct datatype
        if y.dtype.startswith('int'):
            # the T.neq operator returns a vector of 0s and 1s, where 1
            # represents a mistake in prediction
            return T.mean(T.neq(self.y_pred, y))
        else:
            raise NotImplementedError()

# %% [markdown]
# #### My loading functions

# %%
import pandas as pd
import numpy as np
import gc

def load_my_data(fname='../prepare_data/small_meth_feat_vect.csv'):
    """Load my data from file into np.arrays.
    
    It uses int8 for memory efficiency, and speed. Later the values will be
    used as float64 and int32, but pandas double memory usage during loading, so
    I simply can not load them like that. This way the memory usage is not double but
    1+small.
    I have to use garbage collector, because pandas read_csv leaves garbage around.
    """
    
    #load data
    print "Loading data... "
    x=pd.read_csv(fname,sep='\t',engine='c',dtype=np.int8,header=None)
    #shuffle rows
    #this is not necessary it is juts for safety now
    x=x.reindex(np.random.permutation(x.index)).reset_index(drop=True)

    y=np.array(x.iloc[:,-1])
    x=np.array(x.iloc[:,:-1])
    
    # for some reason not everything is cleaned up
    #when using the pandas read_csv
    gc.collect()
    
    return x,y


def load_data(N_train=8000,N_valid=1000,N_test=1000,radius=1000):
    """Load and segment my data into random train,valid,test sets for theano."""
    x,y=load_my_data()

    #select a random subset of data
    rng = np.random.RandomState(23455) # not so random now
    perm=np.arange(100000)#rng.permutation(100000)
    train_idx=perm[:N_train]
    valid_idx=perm[N_train:N_train+N_valid]
    test_idx=perm[N_train+N_valid:N_train+N_valid+N_test]
    
    my_train_set_x=theano.shared(np.float64(x[train_idx,1000-radius:1000+radius]))
    my_valid_set_x=theano.shared(np.float64(x[valid_idx,1000-radius:1000+radius]))
    my_test_set_x=theano.shared(np.float64(x[test_idx,1000-radius:1000+radius]))

    my_train_set_y=theano.shared(np.int32(y[train_idx]))
    my_valid_set_y=theano.shared(np.int32(y[valid_idx]))
    my_test_set_y=theano.shared(np.int32(y[test_idx]))

    return ((my_train_set_x,my_train_set_y),
            (my_valid_set_x,my_valid_set_y),
            (my_test_set_x,my_test_set_y))

# %% [markdown]
# ### From tutorial

# %%
def sgd_optimization_meth(learning_rate=0.13, n_epochs=1000,
                          batch_size=600,
                          N_train=8000,N_valid=1000,N_test=1000,radius=1000):
    """
    Demonstrate stochastic gradient descent optimization of a log-linear
    model

    This is demonstrated on MNIST.

    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
                          gradient)

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer

    :type dataset: string
    :param dataset: the path of the MNIST dataset file from
                 http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz

    """
    datasets = load_data(N_train=N_train,N_valid=N_valid,N_test=N_test,radius=radius)

    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]

    # compute number of minibatches for training, validation and testing
    n_train_batches = train_set_x.get_value(borrow=True).shape[0] / batch_size
    n_valid_batches = valid_set_x.get_value(borrow=True).shape[0] / batch_size
    n_test_batches = test_set_x.get_value(borrow=True).shape[0] / batch_size

    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print '... building the model'

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch

    # generate symbolic variables for input (x and y represent a
    # minibatch)
    x = T.matrix('x')  # data, presented as rasterized images
    y = T.ivector('y')  # labels, presented as 1D vector of [int] labels

    # construct the logistic regression class
    # Each MNIST image has size 28*28
    classifier = LogisticRegression(input=x, n_in= 2*radius, n_out=2)

    # the cost we minimize during training is the negative log likelihood of
    # the model in symbolic format
    cost = classifier.negative_log_likelihood(y)

    # compiling a Theano function that computes the mistakes that are made by
    # the model on a minibatch
    test_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: test_set_x[index * batch_size: (index + 1) * batch_size],
            y: test_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    validate_model = theano.function(
        inputs=[index],
        outputs=classifier.errors(y),
        givens={
            x: valid_set_x[index * batch_size: (index + 1) * batch_size],
            y: valid_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    # compute the gradient of cost with respect to theta = (W,b)
    g_W = T.grad(cost=cost, wrt=classifier.W)
    g_b = T.grad(cost=cost, wrt=classifier.b)

    # start-snippet-3
    # specify how to update the parameters of the model as a list of
    # (variable, update expression) pairs.
    updates = [(classifier.W, classifier.W - learning_rate * g_W),
               (classifier.b, classifier.b - learning_rate * g_b)]

    # compiling a Theano function `train_model` that returns the cost, but in
    # the same time updates the parameter of the model based on the rules
    # defined in `updates`
    train_model = theano.function(
        inputs=[index],
        outputs=cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )
    # end-snippet-3

    ###############
    # TRAIN MODEL #
    ###############
    print '... training the model'
    # early-stopping parameters
    patience = 5000  # look as this many examples regardless
    patience_increase = 2  # wait this much longer when a new best is
                                  # found
    improvement_threshold = 0.995  # a relative improvement of this much is
                                  # considered significant
    validation_frequency = min(n_train_batches, patience / 2)
                                  # go through this many
                                  # minibatche before checking the network
                                  # on the validation set; in this case we
                                  # check every epoch

    best_validation_loss = numpy.inf
    test_score = 0.
    start_time = timeit.default_timer()

    done_looping = False
    epoch = 0
    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in xrange(n_train_batches):

            minibatch_avg_cost = train_model(minibatch_index)
            # iteration number
            iter = (epoch - 1) * n_train_batches + minibatch_index

            if (iter + 1) % validation_frequency == 0:
                # compute zero-one loss on validation set
                validation_losses = [validate_model(i)
                                     for i in xrange(n_valid_batches)]
                this_validation_loss = numpy.mean(validation_losses)

                print(
                    'epoch %i, minibatch %i/%i, validation error %f %%' %
                    (
                        epoch,
                        minibatch_index + 1,
                        n_train_batches,
                        this_validation_loss * 100.
                    )
                )

                # if we got the best validation score until now
                if this_validation_loss < best_validation_loss:
                    #improve patience if loss improvement is good enough
                    if this_validation_loss < best_validation_loss *  \
                       improvement_threshold:
                        patience = max(patience, iter * patience_increase)

                    best_validation_loss = this_validation_loss
                    # test it on the test set

                    test_losses = [test_model(i)
                                   for i in xrange(n_test_batches)]
                    test_score = numpy.mean(test_losses)

                    print(
                        (
                            '     epoch %i, minibatch %i/%i, test error of'
                            ' best model %f %%'
                        ) %
                        (
                            epoch,
                            minibatch_index + 1,
                            n_train_batches,
                            test_score * 100.
                        )
                    )

                    # save the best model
                    with open('best_model.pkl', 'w') as f:
                        cPickle.dump(classifier, f)

            if patience <= iter:
                done_looping = True
                break

    end_time = timeit.default_timer()
    print(
        (
            'Optimization complete with best validation score of %f %%,'
            'with test performance %f %%'
        )
        % (best_validation_loss * 100., test_score * 100.)
    )
    print 'The code run for %d epochs, with %f epochs/sec' % (
        epoch, 1. * epoch / (end_time - start_time))

# %%
sgd_optimization_meth(N_train=5000,N_valid=1000,N_test=1000,radius=1000)
# Out:
# Loading data...
# ... building the model
# ... training the model
# epoch 1, minibatch 8/8, validation error 48.000000 %
#      epoch 1, minibatch 8/8, test error of best model 48.666667 %
# epoch 2, minibatch 8/8, validation error 48.000000 %
# epoch 3, minibatch 8/8, validation error 48.000000 %
# epoch 4, minibatch 8/8, validation error 48.000000 %
# epoch 5, minibatch 8/8, validation error 48.000000 %
# epoch 6, minibatch 8/8, validation error 48.000000 %
# epoch 7, minibatch 8/8, validation error 48.000000 %
# epoch 8, minibatch 8/8, validation error 48.000000 %
# epoch 9, minibatch 8/8, validation error 48.000000 %
# epoch 10, minibatch 8/8, validation error 48.000000 %
# epoch 11, minibatch 8/8, validation error 48.000000 %
# epoch 12, minibatch 8/8, validation error 52.000000 %
# epoch 13, minibatch 8/8, validation error 52.000000 %
# epoch 14, minibatch 8/8, validation error 52.000000 %
# epoch 15, minibatch 8/8, validation error 48.000000 %
# epoch 16, minibatch 8/8, validation error 48.000000 %
# epoch 17, minibatch 8/8, validation error 48.000000 %
# epoch 18, minibatch 8/8, validation error 48.000000 %
# epoch 19, minibatch 8/8, validation error 48.000000 %
# epoch 20, minibatch 8/8, validation error 48.000000 %
# epoch 21, minibatch 8/8, validation error 48.000000 %
# epoch 22, minibatch 8/8, validation error 48.000000 %
# epoch 23, minibatch 8/8, validation error 48.000000 %
# epoch 24, minibatch 8/8, validation error 48.000000 %
# epoch 25, minibatch 8/8, validation error 48.000000 %
# epoch 26, minibatch 8/8, validation error 48.000000 %
# epoch 27, minibatch 8/8, validation error 48.000000 %
# epoch 28, minibatch 8/8, validation error 48.000000 %
# epoch 29, minibatch 8/8, validation error 48.000000 %
# epoch 30, minibatch 8/8, validation error 48.000000 %
# epoch 31, minibatch 8/8, validation error 48.000000 %
# epoch 32, minibatch 8/8, validation error 48.000000 %
# epoch 33, minibatch 8/8, validation error 48.000000 %
# epoch 34, minibatch 8/8, validation error 48.000000 %
# epoch 35, minibatch 8/8, validation error 48.000000 %
# epoch 36, minibatch 8/8, validation error 48.000000 %
# epoch 37, minibatch 8/8, validation error 48.000000 %
# epoch 38, minibatch 8/8, validation error 48.166667 %
# epoch 39, minibatch 8/8, validation error 48.000000 %
# epoch 40, minibatch 8/8, validation error 48.166667 %
# epoch 41, minibatch 8/8, validation error 48.166667 %
# epoch 42, minibatch 8/8, validation error 48.166667 %
# epoch 43, minibatch 8/8, validation error 48.166667 %
# epoch 44, minibatch 8/8, validation error 48.166667 %
# epoch 45, minibatch 8/8, validation error 48.166667 %
# epoch 46, minibatch 8/8, validation error 48.166667 %
# epoch 47, minibatch 8/8, validation error 48.166667 %
# epoch 48, minibatch 8/8, validation error 48.166667 %
# epoch 49, minibatch 8/8, validation error 48.166667 %
# epoch 50, minibatch 8/8, validation error 48.166667 %
# epoch 51, minibatch 8/8, validation error 48.166667 %
# epoch 52, minibatch 8/8, validation error 48.166667 %
# epoch 53, minibatch 8/8, validation error 48.166667 %
# epoch 54, minibatch 8/8, validation error 48.166667 %
# epoch 55, minibatch 8/8, validation error 48.000000 %
# epoch 56, minibatch 8/8, validation error 48.000000 %
# epoch 57, minibatch 8/8, validation error 48.000000 %
# epoch 58, minibatch 8/8, validation error 48.000000 %
# epoch 59, minibatch 8/8, validation error 48.166667 %
# epoch 60, minibatch 8/8, validation error 48.166667 %
# epoch 61, minibatch 8/8, validation error 48.166667 %
# epoch 62, minibatch 8/8, validation error 48.166667 %
# epoch 63, minibatch 8/8, validation error 48.166667 %
# epoch 64, minibatch 8/8, validation error 48.166667 %
# epoch 65, minibatch 8/8, validation error 48.166667 %
# epoch 66, minibatch 8/8, validation error 48.166667 %
# epoch 67, minibatch 8/8, validation error 48.166667 %
# epoch 68, minibatch 8/8, validation error 48.166667 %
# epoch 69, minibatch 8/8, validation error 48.000000 %
# epoch 70, minibatch 8/8, validation error 48.166667 %
# epoch 71, minibatch 8/8, validation error 48.000000 %
# epoch 72, minibatch 8/8, validation error 48.166667 %
# epoch 73, minibatch 8/8, validation error 48.166667 %
# epoch 74, minibatch 8/8, validation error 48.166667 %
# epoch 75, minibatch 8/8, validation error 48.166667 %
# epoch 76, minibatch 8/8, validation error 48.166667 %
# epoch 77, minibatch 8/8, validation error 48.166667 %
# epoch 78, minibatch 8/8, validation error 48.000000 %
# epoch 79, minibatch 8/8, validation error 48.000000 %
# epoch 80, minibatch 8/8, validation error 48.000000 %
# epoch 81, minibatch 8/8, validation error 48.000000 %
# epoch 82, minibatch 8/8, validation error 48.000000 %
# epoch 83, minibatch 8/8, validation error 48.000000 %
# epoch 84, minibatch 8/8, validation error 48.000000 %
# epoch 85, minibatch 8/8, validation error 48.000000 %
# epoch 86, minibatch 8/8, validation error 48.000000 %
# epoch 87, minibatch 8/8, validation error 48.000000 %
# epoch 88, minibatch 8/8, validation error 48.000000 %
# epoch 89, minibatch 8/8, validation error 48.000000 %
# epoch 90, minibatch 8/8, validation error 48.000000 %
# epoch 91, minibatch 8/8, validation error 48.000000 %
# epoch 92, minibatch 8/8, validation error 48.000000 %
# epoch 93, minibatch 8/8, validation error 48.000000 %
# epoch 94, minibatch 8/8, validation error 48.000000 %
# epoch 95, minibatch 8/8, validation error 48.000000 %
# epoch 96, minibatch 8/8, validation error 48.000000 %
# epoch 97, minibatch 8/8, validation error 48.000000 %
# epoch 98, minibatch 8/8, validation error 48.000000 %
# epoch 99, minibatch 8/8, validation error 48.000000 %
# epoch 100, minibatch 8/8, validation error 48.000000 %
# epoch 101, minibatch 8/8, validation error 48.000000 %
# epoch 102, minibatch 8/8, validation error 48.000000 %
# epoch 103, minibatch 8/8, validation error 48.000000 %
# epoch 104, minibatch 8/8, validation error 48.000000 %
# epoch 105, minibatch 8/8, validation error 48.000000 %
# epoch 106, minibatch 8/8, validation error 48.000000 %
# epoch 107, minibatch 8/8, validation error 48.000000 %
# epoch 108, minibatch 8/8, validation error 48.000000 %
# epoch 109, minibatch 8/8, validation error 48.000000 %
# epoch 110, minibatch 8/8, validation error 48.000000 %
# epoch 111, minibatch 8/8, validation error 48.000000 %
# epoch 112, minibatch 8/8, validation error 48.000000 %
# epoch 113, minibatch 8/8, validation error 48.000000 %
# epoch 114, minibatch 8/8, validation error 48.000000 %
# epoch 115, minibatch 8/8, validation error 48.000000 %
# epoch 116, minibatch 8/8, validation error 48.000000 %
# epoch 117, minibatch 8/8, validation error 48.000000 %
# epoch 118, minibatch 8/8, validation error 48.000000 %
# epoch 119, minibatch 8/8, validation error 48.000000 %
# epoch 120, minibatch 8/8, validation error 48.000000 %
# epoch 121, minibatch 8/8, validation error 48.000000 %
# epoch 122, minibatch 8/8, validation error 48.000000 %
# epoch 123, minibatch 8/8, validation error 48.000000 %
# epoch 124, minibatch 8/8, validation error 48.000000 %
# epoch 125, minibatch 8/8, validation error 48.000000 %
# epoch 126, minibatch 8/8, validation error 48.000000 %
# epoch 127, minibatch 8/8, validation error 48.000000 %
# epoch 128, minibatch 8/8, validation error 48.000000 %
# epoch 129, minibatch 8/8, validation error 48.000000 %
# epoch 130, minibatch 8/8, validation error 48.000000 %
# epoch 131, minibatch 8/8, validation error 48.000000 %
# epoch 132, minibatch 8/8, validation error 48.000000 %
# epoch 133, minibatch 8/8, validation error 48.000000 %
# epoch 134, minibatch 8/8, validation error 48.000000 %
# epoch 135, minibatch 8/8, validation error 48.000000 %
# epoch 136, minibatch 8/8, validation error 48.000000 %
# epoch 137, minibatch 8/8, validation error 48.000000 %
# epoch 138, minibatch 8/8, validation error 48.000000 %
# epoch 139, minibatch 8/8, validation error 48.000000 %
# epoch 140, minibatch 8/8, validation error 48.000000 %
# epoch 141, minibatch 8/8, validation error 48.000000 %
# epoch 142, minibatch 8/8, validation error 48.000000 %
# epoch 143, minibatch 8/8, validation error 48.000000 %
# epoch 144, minibatch 8/8, validation error 48.000000 %
# epoch 145, minibatch 8/8, validation error 48.000000 %
# epoch 146, minibatch 8/8, validation error 48.000000 %
# epoch 147, minibatch 8/8, validation error 48.000000 %
# epoch 148, minibatch 8/8, validation error 48.000000 %
# epoch 149, minibatch 8/8, validation error 48.000000 %
# epoch 150, minibatch 8/8, validation error 48.000000 %
# epoch 151, minibatch 8/8, validation error 48.000000 %
# epoch 152, minibatch 8/8, validation error 48.000000 %
# epoch 153, minibatch 8/8, validation error 48.000000 %
# epoch 154, minibatch 8/8, validation error 48.000000 %
# epoch 155, minibatch 8/8, validation error 48.000000 %
# epoch 156, minibatch 8/8, validation error 48.000000 %
# epoch 157, minibatch 8/8, validation error 48.000000 %
# epoch 158, minibatch 8/8, validation error 48.000000 %
# epoch 159, minibatch 8/8, validation error 48.000000 %
# epoch 160, minibatch 8/8, validation error 48.000000 %
# epoch 161, minibatch 8/8, validation error 48.000000 %
# epoch 162, minibatch 8/8, validation error 48.000000 %
# epoch 163, minibatch 8/8, validation error 48.000000 %
# epoch 164, minibatch 8/8, validation error 48.000000 %
# epoch 165, minibatch 8/8, validation error 48.000000 %
# epoch 166, minibatch 8/8, validation error 48.000000 %
# epoch 167, minibatch 8/8, validation error 48.000000 %
# epoch 168, minibatch 8/8, validation error 48.000000 %
# epoch 169, minibatch 8/8, validation error 48.000000 %
# epoch 170, minibatch 8/8, validation error 48.000000 %
# epoch 171, minibatch 8/8, validation error 48.000000 %
# epoch 172, minibatch 8/8, validation error 48.000000 %
# epoch 173, minibatch 8/8, validation error 48.000000 %
# epoch 174, minibatch 8/8, validation error 48.000000 %
# epoch 175, minibatch 8/8, validation error 48.000000 %
# epoch 176, minibatch 8/8, validation error 48.000000 %
# epoch 177, minibatch 8/8, validation error 48.000000 %
# epoch 178, minibatch 8/8, validation error 48.000000 %
# epoch 179, minibatch 8/8, validation error 48.000000 %
# epoch 180, minibatch 8/8, validation error 48.000000 %
# epoch 181, minibatch 8/8, validation error 48.000000 %
# epoch 182, minibatch 8/8, validation error 48.000000 %
# epoch 183, minibatch 8/8, validation error 48.000000 %
# epoch 184, minibatch 8/8, validation error 48.000000 %
# epoch 185, minibatch 8/8, validation error 48.000000 %
# epoch 186, minibatch 8/8, validation error 48.000000 %
# epoch 187, minibatch 8/8, validation error 48.000000 %
# epoch 188, minibatch 8/8, validation error 48.000000 %
# epoch 189, minibatch 8/8, validation error 48.000000 %
# epoch 190, minibatch 8/8, validation error 48.000000 %
# epoch 191, minibatch 8/8, validation error 48.000000 %
# epoch 192, minibatch 8/8, validation error 48.000000 %
# epoch 193, minibatch 8/8, validation error 48.000000 %
# epoch 194, minibatch 8/8, validation error 48.000000 %
# epoch 195, minibatch 8/8, validation error 48.000000 %
# epoch 196, minibatch 8/8, validation error 48.000000 %
# epoch 197, minibatch 8/8, validation error 48.000000 %
# epoch 198, minibatch 8/8, validation error 48.000000 %
# epoch 199, minibatch 8/8, validation error 48.000000 %
# epoch 200, minibatch 8/8, validation error 48.000000 %
# epoch 201, minibatch 8/8, validation error 48.000000 %
# epoch 202, minibatch 8/8, validation error 47.833333 %
#      epoch 202, minibatch 8/8, test error of best model 48.500000 %
# epoch 203, minibatch 8/8, validation error 47.833333 %
# epoch 204, minibatch 8/8, validation error 47.833333 %
# epoch 205, minibatch 8/8, validation error 47.833333 %
# epoch 206, minibatch 8/8, validation error 47.833333 %
# epoch 207, minibatch 8/8, validation error 47.833333 %
# epoch 208, minibatch 8/8, validation error 48.000000 %
# epoch 209, minibatch 8/8, validation error 48.000000 %
# epoch 210, minibatch 8/8, validation error 48.000000 %
# epoch 211, minibatch 8/8, validation error 48.000000 %
# epoch 212, minibatch 8/8, validation error 48.000000 %
# epoch 213, minibatch 8/8, validation error 48.000000 %
# epoch 214, minibatch 8/8, validation error 48.000000 %
# epoch 215, minibatch 8/8, validation error 48.000000 %
# epoch 216, minibatch 8/8, validation error 48.000000 %
# epoch 217, minibatch 8/8, validation error 48.000000 %
# epoch 218, minibatch 8/8, validation error 48.000000 %
# epoch 219, minibatch 8/8, validation error 48.000000 %
# epoch 220, minibatch 8/8, validation error 48.000000 %
# epoch 221, minibatch 8/8, validation error 48.000000 %
# epoch 222, minibatch 8/8, validation error 48.000000 %
# epoch 223, minibatch 8/8, validation error 48.000000 %
# epoch 224, minibatch 8/8, validation error 47.833333 %
# epoch 225, minibatch 8/8, validation error 47.833333 %
# epoch 226, minibatch 8/8, validation error 47.833333 %
# epoch 227, minibatch 8/8, validation error 47.833333 %
# epoch 228, minibatch 8/8, validation error 47.833333 %
# epoch 229, minibatch 8/8, validation error 47.833333 %
# epoch 230, minibatch 8/8, validation error 47.833333 %
# epoch 231, minibatch 8/8, validation error 47.833333 %
# epoch 232, minibatch 8/8, validation error 47.833333 %
# epoch 233, minibatch 8/8, validation error 47.833333 %
# epoch 234, minibatch 8/8, validation error 47.833333 %
# epoch 235, minibatch 8/8, validation error 47.500000 %
#      epoch 235, minibatch 8/8, test error of best model 48.000000 %
# epoch 236, minibatch 8/8, validation error 47.500000 %
# epoch 237, minibatch 8/8, validation error 47.500000 %
# epoch 238, minibatch 8/8, validation error 47.333333 %
#      epoch 238, minibatch 8/8, test error of best model 48.000000 %
# epoch 239, minibatch 8/8, validation error 47.166667 %
#      epoch 239, minibatch 8/8, test error of best model 48.000000 %
# epoch 240, minibatch 8/8, validation error 47.166667 %
# epoch 241, minibatch 8/8, validation error 47.166667 %
# epoch 242, minibatch 8/8, validation error 47.166667 %
# epoch 243, minibatch 8/8, validation error 47.166667 %
# epoch 244, minibatch 8/8, validation error 47.166667 %
# epoch 245, minibatch 8/8, validation error 47.166667 %
# epoch 246, minibatch 8/8, validation error 47.166667 %
# epoch 247, minibatch 8/8, validation error 47.166667 %
# epoch 248, minibatch 8/8, validation error 47.166667 %
# epoch 249, minibatch 8/8, validation error 47.000000 %
#      epoch 249, minibatch 8/8, test error of best model 47.833333 %
# epoch 250, minibatch 8/8, validation error 47.000000 %
# epoch 251, minibatch 8/8, validation error 47.000000 %
# epoch 252, minibatch 8/8, validation error 47.000000 %
# epoch 253, minibatch 8/8, validation error 46.833333 %
#      epoch 253, minibatch 8/8, test error of best model 47.833333 %
# epoch 254, minibatch 8/8, validation error 46.833333 %
# epoch 255, minibatch 8/8, validation error 46.833333 %
# epoch 256, minibatch 8/8, validation error 46.833333 %
# epoch 257, minibatch 8/8, validation error 46.833333 %
# epoch 258, minibatch 8/8, validation error 46.833333 %
# epoch 259, minibatch 8/8, validation error 46.833333 %
# epoch 260, minibatch 8/8, validation error 46.833333 %
# epoch 261, minibatch 8/8, validation error 46.833333 %
# epoch 262, minibatch 8/8, validation error 46.833333 %
# epoch 263, minibatch 8/8, validation error 46.833333 %
# epoch 264, minibatch 8/8, validation error 46.833333 %
# epoch 265, minibatch 8/8, validation error 46.833333 %
# epoch 266, minibatch 8/8, validation error 46.666667 %
#      epoch 266, minibatch 8/8, test error of best model 47.500000 %
# epoch 267, minibatch 8/8, validation error 46.666667 %
# epoch 268, minibatch 8/8, validation error 46.666667 %
# epoch 269, minibatch 8/8, validation error 46.666667 %
# epoch 270, minibatch 8/8, validation error 46.500000 %
#      epoch 270, minibatch 8/8, test error of best model 47.333333 %
# epoch 271, minibatch 8/8, validation error 46.500000 %
# epoch 272, minibatch 8/8, validation error 46.500000 %
# epoch 273, minibatch 8/8, validation error 46.500000 %
# epoch 274, minibatch 8/8, validation error 46.500000 %
# epoch 275, minibatch 8/8, validation error 46.500000 %
# epoch 276, minibatch 8/8, validation error 46.500000 %
# epoch 277, minibatch 8/8, validation error 46.500000 %
# epoch 278, minibatch 8/8, validation error 46.500000 %
# epoch 279, minibatch 8/8, validation error 46.500000 %
# epoch 280, minibatch 8/8, validation error 46.333333 %
#      epoch 280, minibatch 8/8, test error of best model 46.666667 %
# epoch 281, minibatch 8/8, validation error 46.166667 %
#      epoch 281, minibatch 8/8, test error of best model 46.333333 %
# epoch 282, minibatch 8/8, validation error 46.166667 %
# epoch 283, minibatch 8/8, validation error 46.166667 %
# epoch 284, minibatch 8/8, validation error 46.166667 %
# epoch 285, minibatch 8/8, validation error 46.166667 %
# epoch 286, minibatch 8/8, validation error 46.166667 %
# epoch 287, minibatch 8/8, validation error 46.166667 %
# epoch 288, minibatch 8/8, validation error 46.166667 %
# epoch 289, minibatch 8/8, validation error 46.333333 %
# epoch 290, minibatch 8/8, validation error 46.333333 %
# epoch 291, minibatch 8/8, validation error 46.333333 %
# epoch 292, minibatch 8/8, validation error 46.333333 %
# epoch 293, minibatch 8/8, validation error 46.333333 %
# epoch 294, minibatch 8/8, validation error 46.333333 %
# epoch 295, minibatch 8/8, validation error 46.000000 %
#      epoch 295, minibatch 8/8, test error of best model 45.666667 %
# epoch 296, minibatch 8/8, validation error 46.000000 %
# epoch 297, minibatch 8/8, validation error 46.000000 %
# epoch 298, minibatch 8/8, validation error 46.000000 %
# epoch 299, minibatch 8/8, validation error 46.000000 %
# epoch 300, minibatch 8/8, validation error 46.000000 %
# epoch 301, minibatch 8/8, validation error 46.000000 %
# epoch 302, minibatch 8/8, validation error 46.000000 %
# epoch 303, minibatch 8/8, validation error 46.000000 %
# epoch 304, minibatch 8/8, validation error 46.000000 %
# epoch 305, minibatch 8/8, validation error 46.000000 %
# epoch 306, minibatch 8/8, validation error 46.000000 %
# epoch 307, minibatch 8/8, validation error 46.000000 %
# epoch 308, minibatch 8/8, validation error 46.000000 %
# epoch 309, minibatch 8/8, validation error 46.166667 %
# epoch 310, minibatch 8/8, validation error 46.166667 %
# epoch 311, minibatch 8/8, validation error 46.166667 %
# epoch 312, minibatch 8/8, validation error 46.000000 %
# epoch 313, minibatch 8/8, validation error 45.833333 %
#      epoch 313, minibatch 8/8, test error of best model 44.666667 %
# epoch 314, minibatch 8/8, validation error 45.833333 %
# epoch 315, minibatch 8/8, validation error 45.500000 %
#      epoch 315, minibatch 8/8, test error of best model 44.666667 %
# epoch 316, minibatch 8/8, validation error 45.333333 %
#      epoch 316, minibatch 8/8, test error of best model 44.833333 %
# epoch 317, minibatch 8/8, validation error 45.833333 %
# epoch 318, minibatch 8/8, validation error 45.500000 %
# epoch 319, minibatch 8/8, validation error 46.166667 %
# epoch 320, minibatch 8/8, validation error 44.833333 %
#      epoch 320, minibatch 8/8, test error of best model 44.166667 %
# epoch 321, minibatch 8/8, validation error 46.000000 %
# epoch 322, minibatch 8/8, validation error 44.833333 %
# epoch 323, minibatch 8/8, validation error 44.833333 %
# epoch 324, minibatch 8/8, validation error 44.833333 %
# epoch 325, minibatch 8/8, validation error 44.833333 %
# epoch 326, minibatch 8/8, validation error 44.666667 %
#      epoch 326, minibatch 8/8, test error of best model 44.000000 %
# epoch 327, minibatch 8/8, validation error 44.666667 %
# epoch 328, minibatch 8/8, validation error 44.500000 %
#      epoch 328, minibatch 8/8, test error of best model 43.666667 %
# epoch 329, minibatch 8/8, validation error 44.500000 %
# epoch 330, minibatch 8/8, validation error 44.666667 %
# epoch 331, minibatch 8/8, validation error 44.833333 %
# epoch 332, minibatch 8/8, validation error 46.166667 %
# epoch 333, minibatch 8/8, validation error 46.166667 %
# epoch 334, minibatch 8/8, validation error 46.166667 %
# epoch 335, minibatch 8/8, validation error 46.166667 %
# epoch 336, minibatch 8/8, validation error 46.166667 %
# epoch 337, minibatch 8/8, validation error 45.833333 %
# epoch 338, minibatch 8/8, validation error 44.333333 %
#      epoch 338, minibatch 8/8, test error of best model 44.000000 %
# epoch 339, minibatch 8/8, validation error 44.500000 %
# epoch 340, minibatch 8/8, validation error 44.333333 %
# epoch 341, minibatch 8/8, validation error 51.500000 %
# epoch 342, minibatch 8/8, validation error 51.500000 %
# epoch 343, minibatch 8/8, validation error 51.500000 %
# epoch 344, minibatch 8/8, validation error 51.666667 %
# epoch 345, minibatch 8/8, validation error 51.666667 %
# epoch 346, minibatch 8/8, validation error 51.666667 %
# epoch 347, minibatch 8/8, validation error 51.666667 %
# epoch 348, minibatch 8/8, validation error 51.666667 %
# epoch 349, minibatch 8/8, validation error 51.500000 %
# epoch 350, minibatch 8/8, validation error 51.500000 %
# epoch 351, minibatch 8/8, validation error 51.500000 %
# epoch 352, minibatch 8/8, validation error 51.500000 %
# epoch 353, minibatch 8/8, validation error 51.500000 %
# epoch 354, minibatch 8/8, validation error 51.500000 %
# epoch 355, minibatch 8/8, validation error 51.333333 %
# epoch 356, minibatch 8/8, validation error 51.333333 %
# epoch 357, minibatch 8/8, validation error 51.166667 %
# epoch 358, minibatch 8/8, validation error 51.166667 %
# epoch 359, minibatch 8/8, validation error 51.166667 %
# epoch 360, minibatch 8/8, validation error 51.166667 %
# epoch 361, minibatch 8/8, validation error 51.166667 %
# epoch 362, minibatch 8/8, validation error 51.166667 %
# epoch 363, minibatch 8/8, validation error 51.166667 %
# epoch 364, minibatch 8/8, validation error 51.166667 %
# epoch 365, minibatch 8/8, validation error 51.166667 %
# epoch 366, minibatch 8/8, validation error 51.166667 %
# epoch 367, minibatch 8/8, validation error 51.166667 %
# epoch 368, minibatch 8/8, validation error 51.166667 %
# epoch 369, minibatch 8/8, validation error 51.166667 %
# epoch 370, minibatch 8/8, validation error 51.166667 %
# epoch 371, minibatch 8/8, validation error 51.166667 %
# epoch 372, minibatch 8/8, validation error 51.166667 %
# epoch 373, minibatch 8/8, validation error 51.166667 %
# epoch 374, minibatch 8/8, validation error 51.333333 %
# epoch 375, minibatch 8/8, validation error 51.333333 %
# epoch 376, minibatch 8/8, validation error 51.333333 %
# epoch 377, minibatch 8/8, validation error 51.333333 %
# epoch 378, minibatch 8/8, validation error 51.333333 %
# epoch 379, minibatch 8/8, validation error 51.333333 %
# epoch 380, minibatch 8/8, validation error 51.333333 %
# epoch 381, minibatch 8/8, validation error 51.333333 %
# epoch 382, minibatch 8/8, validation error 51.333333 %
# epoch 383, minibatch 8/8, validation error 51.333333 %
# epoch 384, minibatch 8/8, validation error 51.333333 %
# epoch 385, minibatch 8/8, validation error 51.333333 %
# epoch 386, minibatch 8/8, validation error 51.333333 %
# epoch 387, minibatch 8/8, validation error 51.333333 %
# epoch 388, minibatch 8/8, validation error 51.333333 %
# epoch 389, minibatch 8/8, validation error 51.333333 %
# epoch 390, minibatch 8/8, validation error 51.333333 %
# epoch 391, minibatch 8/8, validation error 51.333333 %
# epoch 392, minibatch 8/8, validation error 51.333333 %
# epoch 393, minibatch 8/8, validation error 51.333333 %
# epoch 394, minibatch 8/8, validation error 51.333333 %
# epoch 395, minibatch 8/8, validation error 51.333333 %
# epoch 396, minibatch 8/8, validation error 51.333333 %
# epoch 397, minibatch 8/8, validation error 51.166667 %
# epoch 398, minibatch 8/8, validation error 51.000000 %
# epoch 399, minibatch 8/8, validation error 51.000000 %
# epoch 400, minibatch 8/8, validation error 51.000000 %
# epoch 401, minibatch 8/8, validation error 51.166667 %
# epoch 402, minibatch 8/8, validation error 51.166667 %
# epoch 403, minibatch 8/8, validation error 51.000000 %
# epoch 404, minibatch 8/8, validation error 51.000000 %
# epoch 405, minibatch 8/8, validation error 51.000000 %
# epoch 406, minibatch 8/8, validation error 51.000000 %
# epoch 407, minibatch 8/8, validation error 50.833333 %
# epoch 408, minibatch 8/8, validation error 50.833333 %
# epoch 409, minibatch 8/8, validation error 51.000000 %
# epoch 410, minibatch 8/8, validation error 51.000000 %
# epoch 411, minibatch 8/8, validation error 51.000000 %
# epoch 412, minibatch 8/8, validation error 51.000000 %
# epoch 413, minibatch 8/8, validation error 51.000000 %
# epoch 414, minibatch 8/8, validation error 51.000000 %
# epoch 415, minibatch 8/8, validation error 50.666667 %
# epoch 416, minibatch 8/8, validation error 50.666667 %
# epoch 417, minibatch 8/8, validation error 50.666667 %
# epoch 418, minibatch 8/8, validation error 50.666667 %
# epoch 419, minibatch 8/8, validation error 50.666667 %
# epoch 420, minibatch 8/8, validation error 50.500000 %
# epoch 421, minibatch 8/8, validation error 50.500000 %
# epoch 422, minibatch 8/8, validation error 50.500000 %
# epoch 423, minibatch 8/8, validation error 50.500000 %
# epoch 424, minibatch 8/8, validation error 50.000000 %
# epoch 425, minibatch 8/8, validation error 50.000000 %
# epoch 426, minibatch 8/8, validation error 50.166667 %
# epoch 427, minibatch 8/8, validation error 50.166667 %
# epoch 428, minibatch 8/8, validation error 50.166667 %
# epoch 429, minibatch 8/8, validation error 50.166667 %
# epoch 430, minibatch 8/8, validation error 50.000000 %
# epoch 431, minibatch 8/8, validation error 50.000000 %
# epoch 432, minibatch 8/8, validation error 50.000000 %
# epoch 433, minibatch 8/8, validation error 50.000000 %
# epoch 434, minibatch 8/8, validation error 49.833333 %
# epoch 435, minibatch 8/8, validation error 49.833333 %
# epoch 436, minibatch 8/8, validation error 49.833333 %
# epoch 437, minibatch 8/8, validation error 49.833333 %
# epoch 438, minibatch 8/8, validation error 49.666667 %
# epoch 439, minibatch 8/8, validation error 49.833333 %
# epoch 440, minibatch 8/8, validation error 49.833333 %
# epoch 441, minibatch 8/8, validation error 49.833333 %
# epoch 442, minibatch 8/8, validation error 49.666667 %
# epoch 443, minibatch 8/8, validation error 49.666667 %
# epoch 444, minibatch 8/8, validation error 49.666667 %
# epoch 445, minibatch 8/8, validation error 49.666667 %
# epoch 446, minibatch 8/8, validation error 49.666667 %
# epoch 447, minibatch 8/8, validation error 49.666667 %
# epoch 448, minibatch 8/8, validation error 49.666667 %
# epoch 449, minibatch 8/8, validation error 49.666667 %
# epoch 450, minibatch 8/8, validation error 49.333333 %
# epoch 451, minibatch 8/8, validation error 49.333333 %
# epoch 452, minibatch 8/8, validation error 49.166667 %
# epoch 453, minibatch 8/8, validation error 49.333333 %
# epoch 454, minibatch 8/8, validation error 49.333333 %
# epoch 455, minibatch 8/8, validation error 49.333333 %
# epoch 456, minibatch 8/8, validation error 49.166667 %
# epoch 457, minibatch 8/8, validation error 49.333333 %
# epoch 458, minibatch 8/8, validation error 49.166667 %
# epoch 459, minibatch 8/8, validation error 49.333333 %
# epoch 460, minibatch 8/8, validation error 49.500000 %
# epoch 461, minibatch 8/8, validation error 49.500000 %
# epoch 462, minibatch 8/8, validation error 49.333333 %
# epoch 463, minibatch 8/8, validation error 49.333333 %
# epoch 464, minibatch 8/8, validation error 49.333333 %
# epoch 465, minibatch 8/8, validation error 49.333333 %
# epoch 466, minibatch 8/8, validation error 49.333333 %
# epoch 467, minibatch 8/8, validation error 49.333333 %
# epoch 468, minibatch 8/8, validation error 49.333333 %
# epoch 469, minibatch 8/8, validation error 49.333333 %
# epoch 470, minibatch 8/8, validation error 49.500000 %
# epoch 471, minibatch 8/8, validation error 49.500000 %
# epoch 472, minibatch 8/8, validation error 49.500000 %
# epoch 473, minibatch 8/8, validation error 49.500000 %
# epoch 474, minibatch 8/8, validation error 49.500000 %
# epoch 475, minibatch 8/8, validation error 49.500000 %
# epoch 476, minibatch 8/8, validation error 49.500000 %
# epoch 477, minibatch 8/8, validation error 49.500000 %
# epoch 478, minibatch 8/8, validation error 49.500000 %
# epoch 479, minibatch 8/8, validation error 49.500000 %
# epoch 480, minibatch 8/8, validation error 49.666667 %
# epoch 481, minibatch 8/8, validation error 49.666667 %
# epoch 482, minibatch 8/8, validation error 49.500000 %
# epoch 483, minibatch 8/8, validation error 49.166667 %
# epoch 484, minibatch 8/8, validation error 49.666667 %
# epoch 485, minibatch 8/8, validation error 49.666667 %
# epoch 486, minibatch 8/8, validation error 49.666667 %
# epoch 487, minibatch 8/8, validation error 49.666667 %
# epoch 488, minibatch 8/8, validation error 49.666667 %
# epoch 489, minibatch 8/8, validation error 49.666667 %
# epoch 490, minibatch 8/8, validation error 49.666667 %
# epoch 491, minibatch 8/8, validation error 49.666667 %
# epoch 492, minibatch 8/8, validation error 49.666667 %
# epoch 493, minibatch 8/8, validation error 49.833333 %
# epoch 494, minibatch 8/8, validation error 49.833333 %
# epoch 495, minibatch 8/8, validation error 49.833333 %
# epoch 496, minibatch 8/8, validation error 49.833333 %
# epoch 497, minibatch 8/8, validation error 50.000000 %
# epoch 498, minibatch 8/8, validation error 49.500000 %
# epoch 499, minibatch 8/8, validation error 49.833333 %
# epoch 500, minibatch 8/8, validation error 49.833333 %
# epoch 501, minibatch 8/8, validation error 50.000000 %
# epoch 502, minibatch 8/8, validation error 50.000000 %
# epoch 503, minibatch 8/8, validation error 50.000000 %
# epoch 504, minibatch 8/8, validation error 50.000000 %
# epoch 505, minibatch 8/8, validation error 50.000000 %
# epoch 506, minibatch 8/8, validation error 50.000000 %
# epoch 507, minibatch 8/8, validation error 50.333333 %
# epoch 508, minibatch 8/8, validation error 50.166667 %
# epoch 509, minibatch 8/8, validation error 50.333333 %
# epoch 510, minibatch 8/8, validation error 50.333333 %
# epoch 511, minibatch 8/8, validation error 50.166667 %
# epoch 512, minibatch 8/8, validation error 50.000000 %
# epoch 513, minibatch 8/8, validation error 49.833333 %
# epoch 514, minibatch 8/8, validation error 49.833333 %
# epoch 515, minibatch 8/8, validation error 50.166667 %
# epoch 516, minibatch 8/8, validation error 50.166667 %
# epoch 517, minibatch 8/8, validation error 50.000000 %
# epoch 518, minibatch 8/8, validation error 50.000000 %
# epoch 519, minibatch 8/8, validation error 49.833333 %
# epoch 520, minibatch 8/8, validation error 50.000000 %
# epoch 521, minibatch 8/8, validation error 49.833333 %
# epoch 522, minibatch 8/8, validation error 49.666667 %
# epoch 523, minibatch 8/8, validation error 50.000000 %
# epoch 524, minibatch 8/8, validation error 49.666667 %
# epoch 525, minibatch 8/8, validation error 50.000000 %
# epoch 526, minibatch 8/8, validation error 49.666667 %
# epoch 527, minibatch 8/8, validation error 49.666667 %
# epoch 528, minibatch 8/8, validation error 49.666667 %
# epoch 529, minibatch 8/8, validation error 49.666667 %
# epoch 530, minibatch 8/8, validation error 49.500000 %
# epoch 531, minibatch 8/8, validation error 49.500000 %
# epoch 532, minibatch 8/8, validation error 49.500000 %
# epoch 533, minibatch 8/8, validation error 49.500000 %
# epoch 534, minibatch 8/8, validation error 49.500000 %
# epoch 535, minibatch 8/8, validation error 49.833333 %
# epoch 536, minibatch 8/8, validation error 49.833333 %
# epoch 537, minibatch 8/8, validation error 49.833333 %
# epoch 538, minibatch 8/8, validation error 49.833333 %
# epoch 539, minibatch 8/8, validation error 49.833333 %
# epoch 540, minibatch 8/8, validation error 49.333333 %
# epoch 541, minibatch 8/8, validation error 49.000000 %
# epoch 542, minibatch 8/8, validation error 49.000000 %
# epoch 543, minibatch 8/8, validation error 49.166667 %
# epoch 544, minibatch 8/8, validation error 49.166667 %
# epoch 545, minibatch 8/8, validation error 49.166667 %
# epoch 546, minibatch 8/8, validation error 49.166667 %
# epoch 547, minibatch 8/8, validation error 49.166667 %
# epoch 548, minibatch 8/8, validation error 49.166667 %
# epoch 549, minibatch 8/8, validation error 49.333333 %
# epoch 550, minibatch 8/8, validation error 49.333333 %
# epoch 551, minibatch 8/8, validation error 49.166667 %
# epoch 552, minibatch 8/8, validation error 49.333333 %
# epoch 553, minibatch 8/8, validation error 49.333333 %
# epoch 554, minibatch 8/8, validation error 49.500000 %
# epoch 555, minibatch 8/8, validation error 49.333333 %
# epoch 556, minibatch 8/8, validation error 49.666667 %
# epoch 557, minibatch 8/8, validation error 49.500000 %
# epoch 558, minibatch 8/8, validation error 49.500000 %
# epoch 559, minibatch 8/8, validation error 49.500000 %
# epoch 560, minibatch 8/8, validation error 49.833333 %
# epoch 561, minibatch 8/8, validation error 49.666667 %
# epoch 562, minibatch 8/8, validation error 49.666667 %
# epoch 563, minibatch 8/8, validation error 49.833333 %
# epoch 564, minibatch 8/8, validation error 49.500000 %
# epoch 565, minibatch 8/8, validation error 49.666667 %
# epoch 566, minibatch 8/8, validation error 49.500000 %
# epoch 567, minibatch 8/8, validation error 49.666667 %
# epoch 568, minibatch 8/8, validation error 49.666667 %
# epoch 569, minibatch 8/8, validation error 49.333333 %
# epoch 570, minibatch 8/8, validation error 49.500000 %
# epoch 571, minibatch 8/8, validation error 49.500000 %
# epoch 572, minibatch 8/8, validation error 49.500000 %
# epoch 573, minibatch 8/8, validation error 49.500000 %
# epoch 574, minibatch 8/8, validation error 49.500000 %
# epoch 575, minibatch 8/8, validation error 49.833333 %
# epoch 576, minibatch 8/8, validation error 49.833333 %
# epoch 577, minibatch 8/8, validation error 49.833333 %
# epoch 578, minibatch 8/8, validation error 49.666667 %
# epoch 579, minibatch 8/8, validation error 49.666667 %
# epoch 580, minibatch 8/8, validation error 49.666667 %
# epoch 581, minibatch 8/8, validation error 49.666667 %
# epoch 582, minibatch 8/8, validation error 49.833333 %
# epoch 583, minibatch 8/8, validation error 49.666667 %
# epoch 584, minibatch 8/8, validation error 50.166667 %
# epoch 585, minibatch 8/8, validation error 48.333333 %
# epoch 586, minibatch 8/8, validation error 47.666667 %
# epoch 587, minibatch 8/8, validation error 47.833333 %
# epoch 588, minibatch 8/8, validation error 48.000000 %
# epoch 589, minibatch 8/8, validation error 48.000000 %
# epoch 590, minibatch 8/8, validation error 48.000000 %
# epoch 591, minibatch 8/8, validation error 48.000000 %
# epoch 592, minibatch 8/8, validation error 48.000000 %
# epoch 593, minibatch 8/8, validation error 48.000000 %
# epoch 594, minibatch 8/8, validation error 48.000000 %
# epoch 595, minibatch 8/8, validation error 48.000000 %
# epoch 596, minibatch 8/8, validation error 48.000000 %
# epoch 597, minibatch 8/8, validation error 47.666667 %
# epoch 598, minibatch 8/8, validation error 47.666667 %
# epoch 599, minibatch 8/8, validation error 47.833333 %
# epoch 600, minibatch 8/8, validation error 48.000000 %
# epoch 601, minibatch 8/8, validation error 48.333333 %
# epoch 602, minibatch 8/8, validation error 48.333333 %
# epoch 603, minibatch 8/8, validation error 48.166667 %
# epoch 604, minibatch 8/8, validation error 48.166667 %
# epoch 605, minibatch 8/8, validation error 48.666667 %
# epoch 606, minibatch 8/8, validation error 49.833333 %
# epoch 607, minibatch 8/8, validation error 50.000000 %
# epoch 608, minibatch 8/8, validation error 49.833333 %
# epoch 609, minibatch 8/8, validation error 49.666667 %
# epoch 610, minibatch 8/8, validation error 49.833333 %
# epoch 611, minibatch 8/8, validation error 50.000000 %
# epoch 612, minibatch 8/8, validation error 49.833333 %
# epoch 613, minibatch 8/8, validation error 49.833333 %
# epoch 614, minibatch 8/8, validation error 50.000000 %
# epoch 615, minibatch 8/8, validation error 50.000000 %
# epoch 616, minibatch 8/8, validation error 50.166667 %
# epoch 617, minibatch 8/8, validation error 50.166667 %
# epoch 618, minibatch 8/8, validation error 49.833333 %
# epoch 619, minibatch 8/8, validation error 49.666667 %
# epoch 620, minibatch 8/8, validation error 47.500000 %
# epoch 621, minibatch 8/8, validation error 46.166667 %
# epoch 622, minibatch 8/8, validation error 43.666667 %
#      epoch 622, minibatch 8/8, test error of best model 43.000000 %
# epoch 623, minibatch 8/8, validation error 44.333333 %
# epoch 624, minibatch 8/8, validation error 44.500000 %
# epoch 625, minibatch 8/8, validation error 44.500000 %
# epoch 626, minibatch 8/8, validation error 44.500000 %
# epoch 627, minibatch 8/8, validation error 44.166667 %
# epoch 628, minibatch 8/8, validation error 44.166667 %
# epoch 629, minibatch 8/8, validation error 44.166667 %
# epoch 630, minibatch 8/8, validation error 44.333333 %
# epoch 631, minibatch 8/8, validation error 44.166667 %
# epoch 632, minibatch 8/8, validation error 44.333333 %
# epoch 633, minibatch 8/8, validation error 44.333333 %
# epoch 634, minibatch 8/8, validation error 44.333333 %
# epoch 635, minibatch 8/8, validation error 44.333333 %
# epoch 636, minibatch 8/8, validation error 44.333333 %
# epoch 637, minibatch 8/8, validation error 44.333333 %
# epoch 638, minibatch 8/8, validation error 44.166667 %
# epoch 639, minibatch 8/8, validation error 44.500000 %
# epoch 640, minibatch 8/8, validation error 44.333333 %
# epoch 641, minibatch 8/8, validation error 44.333333 %
# epoch 642, minibatch 8/8, validation error 44.500000 %
# epoch 643, minibatch 8/8, validation error 44.166667 %
# epoch 644, minibatch 8/8, validation error 44.166667 %
# epoch 645, minibatch 8/8, validation error 44.333333 %
# epoch 646, minibatch 8/8, validation error 44.333333 %
# epoch 647, minibatch 8/8, validation error 44.333333 %
# epoch 648, minibatch 8/8, validation error 44.166667 %
# epoch 649, minibatch 8/8, validation error 44.166667 %
# epoch 650, minibatch 8/8, validation error 44.166667 %
# epoch 651, minibatch 8/8, validation error 44.333333 %
# epoch 652, minibatch 8/8, validation error 44.333333 %
# epoch 653, minibatch 8/8, validation error 44.333333 %
# epoch 654, minibatch 8/8, validation error 44.333333 %
# epoch 655, minibatch 8/8, validation error 44.333333 %
# epoch 656, minibatch 8/8, validation error 44.000000 %
# epoch 657, minibatch 8/8, validation error 44.000000 %
# epoch 658, minibatch 8/8, validation error 44.000000 %
# epoch 659, minibatch 8/8, validation error 44.000000 %
# epoch 660, minibatch 8/8, validation error 44.333333 %
# epoch 661, minibatch 8/8, validation error 44.500000 %
# epoch 662, minibatch 8/8, validation error 44.333333 %
# epoch 663, minibatch 8/8, validation error 44.166667 %
# epoch 664, minibatch 8/8, validation error 44.166667 %
# epoch 665, minibatch 8/8, validation error 44.666667 %
# epoch 666, minibatch 8/8, validation error 44.333333 %
# epoch 667, minibatch 8/8, validation error 44.166667 %
# epoch 668, minibatch 8/8, validation error 44.666667 %
# epoch 669, minibatch 8/8, validation error 44.500000 %
# epoch 670, minibatch 8/8, validation error 44.500000 %
# epoch 671, minibatch 8/8, validation error 44.500000 %
# epoch 672, minibatch 8/8, validation error 44.500000 %
# epoch 673, minibatch 8/8, validation error 44.500000 %
# epoch 674, minibatch 8/8, validation error 44.500000 %
# epoch 675, minibatch 8/8, validation error 44.500000 %
# epoch 676, minibatch 8/8, validation error 44.500000 %
# epoch 677, minibatch 8/8, validation error 44.500000 %
# epoch 678, minibatch 8/8, validation error 44.500000 %
# epoch 679, minibatch 8/8, validation error 44.500000 %
# epoch 680, minibatch 8/8, validation error 44.166667 %
# epoch 681, minibatch 8/8, validation error 44.500000 %
# epoch 682, minibatch 8/8, validation error 44.666667 %
# epoch 683, minibatch 8/8, validation error 44.333333 %
# epoch 684, minibatch 8/8, validation error 44.500000 %
# epoch 685, minibatch 8/8, validation error 44.333333 %
# epoch 686, minibatch 8/8, validation error 44.333333 %
# epoch 687, minibatch 8/8, validation error 44.333333 %
# epoch 688, minibatch 8/8, validation error 44.333333 %
# epoch 689, minibatch 8/8, validation error 44.666667 %
# epoch 690, minibatch 8/8, validation error 44.333333 %
# epoch 691, minibatch 8/8, validation error 44.333333 %
# epoch 692, minibatch 8/8, validation error 44.000000 %
# epoch 693, minibatch 8/8, validation error 44.333333 %
# epoch 694, minibatch 8/8, validation error 43.833333 %
# epoch 695, minibatch 8/8, validation error 43.833333 %
# epoch 696, minibatch 8/8, validation error 44.000000 %
# epoch 697, minibatch 8/8, validation error 44.166667 %
# epoch 698, minibatch 8/8, validation error 44.333333 %
# epoch 699, minibatch 8/8, validation error 44.000000 %
# epoch 700, minibatch 8/8, validation error 44.333333 %
# epoch 701, minibatch 8/8, validation error 44.833333 %
# epoch 702, minibatch 8/8, validation error 45.333333 %
# epoch 703, minibatch 8/8, validation error 45.000000 %
# epoch 704, minibatch 8/8, validation error 44.833333 %
# epoch 705, minibatch 8/8, validation error 44.166667 %
# epoch 706, minibatch 8/8, validation error 44.500000 %
# epoch 707, minibatch 8/8, validation error 44.333333 %
# epoch 708, minibatch 8/8, validation error 44.000000 %
# epoch 709, minibatch 8/8, validation error 44.000000 %
# epoch 710, minibatch 8/8, validation error 44.166667 %
# epoch 711, minibatch 8/8, validation error 42.833333 %
#      epoch 711, minibatch 8/8, test error of best model 43.500000 %
# epoch 712, minibatch 8/8, validation error 42.500000 %
#      epoch 712, minibatch 8/8, test error of best model 43.833333 %
# epoch 713, minibatch 8/8, validation error 45.000000 %
# epoch 714, minibatch 8/8, validation error 49.333333 %
# epoch 715, minibatch 8/8, validation error 49.500000 %
# epoch 716, minibatch 8/8, validation error 49.500000 %
# epoch 717, minibatch 8/8, validation error 49.500000 %
# epoch 718, minibatch 8/8, validation error 49.666667 %
# epoch 719, minibatch 8/8, validation error 49.666667 %
# epoch 720, minibatch 8/8, validation error 49.666667 %
# epoch 721, minibatch 8/8, validation error 49.500000 %
# epoch 722, minibatch 8/8, validation error 49.500000 %
# epoch 723, minibatch 8/8, validation error 49.666667 %
# epoch 724, minibatch 8/8, validation error 49.833333 %
# epoch 725, minibatch 8/8, validation error 49.666667 %
# epoch 726, minibatch 8/8, validation error 49.666667 %
# epoch 727, minibatch 8/8, validation error 49.666667 %
# epoch 728, minibatch 8/8, validation error 49.500000 %
# epoch 729, minibatch 8/8, validation error 49.333333 %
# epoch 730, minibatch 8/8, validation error 49.666667 %
# epoch 731, minibatch 8/8, validation error 49.833333 %
# epoch 732, minibatch 8/8, validation error 49.833333 %
# epoch 733, minibatch 8/8, validation error 49.833333 %
# epoch 734, minibatch 8/8, validation error 49.833333 %
# epoch 735, minibatch 8/8, validation error 50.000000 %
# epoch 736, minibatch 8/8, validation error 49.833333 %
# epoch 737, minibatch 8/8, validation error 49.666667 %
# epoch 738, minibatch 8/8, validation error 49.666667 %
# epoch 739, minibatch 8/8, validation error 49.666667 %
# epoch 740, minibatch 8/8, validation error 49.666667 %
# epoch 741, minibatch 8/8, validation error 49.666667 %
# epoch 742, minibatch 8/8, validation error 49.666667 %
# epoch 743, minibatch 8/8, validation error 49.666667 %
# epoch 744, minibatch 8/8, validation error 49.500000 %
# epoch 745, minibatch 8/8, validation error 49.333333 %
# epoch 746, minibatch 8/8, validation error 49.333333 %
# epoch 747, minibatch 8/8, validation error 49.166667 %
# epoch 748, minibatch 8/8, validation error 48.500000 %
# epoch 749, minibatch 8/8, validation error 48.500000 %
# epoch 750, minibatch 8/8, validation error 48.500000 %
# epoch 751, minibatch 8/8, validation error 48.500000 %
# epoch 752, minibatch 8/8, validation error 48.500000 %
# epoch 753, minibatch 8/8, validation error 48.666667 %
# epoch 754, minibatch 8/8, validation error 48.666667 %
# epoch 755, minibatch 8/8, validation error 48.666667 %
# epoch 756, minibatch 8/8, validation error 47.666667 %
# epoch 757, minibatch 8/8, validation error 47.666667 %
# epoch 758, minibatch 8/8, validation error 47.833333 %
# epoch 759, minibatch 8/8, validation error 47.666667 %
# epoch 760, minibatch 8/8, validation error 48.333333 %
# epoch 761, minibatch 8/8, validation error 47.333333 %
# epoch 762, minibatch 8/8, validation error 46.500000 %
# epoch 763, minibatch 8/8, validation error 46.500000 %
# epoch 764, minibatch 8/8, validation error 47.833333 %
# epoch 765, minibatch 8/8, validation error 47.333333 %
# epoch 766, minibatch 8/8, validation error 47.333333 %
# epoch 767, minibatch 8/8, validation error 47.333333 %
# epoch 768, minibatch 8/8, validation error 47.333333 %
# epoch 769, minibatch 8/8, validation error 47.833333 %
# epoch 770, minibatch 8/8, validation error 47.500000 %
# epoch 771, minibatch 8/8, validation error 47.500000 %
# epoch 772, minibatch 8/8, validation error 47.666667 %
# epoch 773, minibatch 8/8, validation error 48.000000 %
# epoch 774, minibatch 8/8, validation error 49.833333 %
# epoch 775, minibatch 8/8, validation error 50.166667 %
# epoch 776, minibatch 8/8, validation error 50.166667 %
# epoch 777, minibatch 8/8, validation error 50.166667 %
# epoch 778, minibatch 8/8, validation error 50.166667 %
# epoch 779, minibatch 8/8, validation error 50.000000 %
# epoch 780, minibatch 8/8, validation error 50.000000 %
# epoch 781, minibatch 8/8, validation error 50.000000 %
# epoch 782, minibatch 8/8, validation error 50.000000 %
# epoch 783, minibatch 8/8, validation error 50.000000 %
# epoch 784, minibatch 8/8, validation error 50.000000 %
# epoch 785, minibatch 8/8, validation error 50.000000 %
# epoch 786, minibatch 8/8, validation error 50.000000 %
# epoch 787, minibatch 8/8, validation error 50.333333 %
# epoch 788, minibatch 8/8, validation error 50.666667 %
# epoch 789, minibatch 8/8, validation error 50.166667 %
# epoch 790, minibatch 8/8, validation error 49.666667 %
# epoch 791, minibatch 8/8, validation error 50.000000 %
# epoch 792, minibatch 8/8, validation error 49.833333 %
# epoch 793, minibatch 8/8, validation error 49.666667 %
# epoch 794, minibatch 8/8, validation error 46.166667 %
# epoch 795, minibatch 8/8, validation error 44.000000 %
# epoch 796, minibatch 8/8, validation error 44.166667 %
# epoch 797, minibatch 8/8, validation error 45.000000 %
# epoch 798, minibatch 8/8, validation error 44.833333 %
# epoch 799, minibatch 8/8, validation error 44.833333 %
# epoch 800, minibatch 8/8, validation error 44.833333 %
# epoch 801, minibatch 8/8, validation error 44.833333 %
# epoch 802, minibatch 8/8, validation error 44.833333 %
# epoch 803, minibatch 8/8, validation error 44.833333 %
# epoch 804, minibatch 8/8, validation error 44.833333 %
# epoch 805, minibatch 8/8, validation error 44.833333 %
# epoch 806, minibatch 8/8, validation error 44.500000 %
# epoch 807, minibatch 8/8, validation error 44.333333 %
# epoch 808, minibatch 8/8, validation error 44.333333 %
# epoch 809, minibatch 8/8, validation error 44.333333 %
# epoch 810, minibatch 8/8, validation error 44.166667 %
# epoch 811, minibatch 8/8, validation error 44.833333 %
# epoch 812, minibatch 8/8, validation error 44.666667 %
# epoch 813, minibatch 8/8, validation error 44.666667 %
# epoch 814, minibatch 8/8, validation error 44.500000 %
# epoch 815, minibatch 8/8, validation error 44.500000 %
# epoch 816, minibatch 8/8, validation error 44.666667 %
# epoch 817, minibatch 8/8, validation error 44.666667 %
# epoch 818, minibatch 8/8, validation error 44.500000 %
# epoch 819, minibatch 8/8, validation error 44.500000 %
# epoch 820, minibatch 8/8, validation error 44.833333 %
# epoch 821, minibatch 8/8, validation error 44.666667 %
# epoch 822, minibatch 8/8, validation error 44.500000 %
# epoch 823, minibatch 8/8, validation error 44.666667 %
# epoch 824, minibatch 8/8, validation error 44.500000 %
# epoch 825, minibatch 8/8, validation error 44.833333 %
# epoch 826, minibatch 8/8, validation error 44.166667 %
# epoch 827, minibatch 8/8, validation error 44.666667 %
# epoch 828, minibatch 8/8, validation error 45.333333 %
# epoch 829, minibatch 8/8, validation error 44.833333 %
# epoch 830, minibatch 8/8, validation error 44.833333 %
# epoch 831, minibatch 8/8, validation error 44.333333 %
# epoch 832, minibatch 8/8, validation error 44.333333 %
# epoch 833, minibatch 8/8, validation error 44.333333 %
# epoch 834, minibatch 8/8, validation error 44.500000 %
# epoch 835, minibatch 8/8, validation error 44.500000 %
# epoch 836, minibatch 8/8, validation error 44.666667 %
# epoch 837, minibatch 8/8, validation error 44.666667 %
# epoch 838, minibatch 8/8, validation error 45.000000 %
# epoch 839, minibatch 8/8, validation error 44.833333 %
# epoch 840, minibatch 8/8, validation error 44.666667 %
# epoch 841, minibatch 8/8, validation error 44.833333 %
# epoch 842, minibatch 8/8, validation error 44.666667 %
# epoch 843, minibatch 8/8, validation error 44.833333 %
# epoch 844, minibatch 8/8, validation error 44.833333 %
# epoch 845, minibatch 8/8, validation error 44.166667 %
# epoch 846, minibatch 8/8, validation error 44.166667 %
# epoch 847, minibatch 8/8, validation error 44.500000 %
# epoch 848, minibatch 8/8, validation error 45.500000 %
# epoch 849, minibatch 8/8, validation error 45.500000 %
# epoch 850, minibatch 8/8, validation error 45.666667 %
# epoch 851, minibatch 8/8, validation error 45.500000 %
# epoch 852, minibatch 8/8, validation error 45.333333 %
# epoch 853, minibatch 8/8, validation error 45.000000 %
# epoch 854, minibatch 8/8, validation error 44.500000 %
# epoch 855, minibatch 8/8, validation error 44.500000 %
# epoch 856, minibatch 8/8, validation error 44.500000 %
# epoch 857, minibatch 8/8, validation error 44.500000 %
# epoch 858, minibatch 8/8, validation error 44.333333 %
# epoch 859, minibatch 8/8, validation error 44.000000 %
# epoch 860, minibatch 8/8, validation error 44.166667 %
# epoch 861, minibatch 8/8, validation error 45.500000 %
# epoch 862, minibatch 8/8, validation error 44.833333 %
# epoch 863, minibatch 8/8, validation error 46.833333 %
# epoch 864, minibatch 8/8, validation error 47.500000 %
# epoch 865, minibatch 8/8, validation error 49.333333 %
# epoch 866, minibatch 8/8, validation error 50.166667 %
# epoch 867, minibatch 8/8, validation error 50.166667 %
# epoch 868, minibatch 8/8, validation error 50.000000 %
# epoch 869, minibatch 8/8, validation error 49.333333 %
# epoch 870, minibatch 8/8, validation error 49.666667 %
# epoch 871, minibatch 8/8, validation error 49.666667 %
# epoch 872, minibatch 8/8, validation error 49.500000 %
# epoch 873, minibatch 8/8, validation error 50.333333 %
# epoch 874, minibatch 8/8, validation error 50.333333 %
# epoch 875, minibatch 8/8, validation error 49.666667 %
# epoch 876, minibatch 8/8, validation error 49.500000 %
# epoch 877, minibatch 8/8, validation error 49.500000 %
# epoch 878, minibatch 8/8, validation error 49.166667 %
# epoch 879, minibatch 8/8, validation error 49.333333 %
# epoch 880, minibatch 8/8, validation error 49.333333 %
# epoch 881, minibatch 8/8, validation error 49.500000 %
# epoch 882, minibatch 8/8, validation error 49.833333 %
# epoch 883, minibatch 8/8, validation error 49.666667 %
# epoch 884, minibatch 8/8, validation error 49.833333 %
# epoch 885, minibatch 8/8, validation error 49.833333 %
# epoch 886, minibatch 8/8, validation error 49.666667 %
# epoch 887, minibatch 8/8, validation error 47.500000 %
# epoch 888, minibatch 8/8, validation error 45.666667 %
# epoch 889, minibatch 8/8, validation error 45.166667 %
# epoch 890, minibatch 8/8, validation error 44.833333 %
# epoch 891, minibatch 8/8, validation error 44.333333 %
# epoch 892, minibatch 8/8, validation error 43.666667 %
# epoch 893, minibatch 8/8, validation error 43.500000 %
# epoch 894, minibatch 8/8, validation error 43.333333 %
# epoch 895, minibatch 8/8, validation error 43.333333 %
# epoch 896, minibatch 8/8, validation error 43.500000 %
# epoch 897, minibatch 8/8, validation error 43.666667 %
# epoch 898, minibatch 8/8, validation error 43.500000 %
# epoch 899, minibatch 8/8, validation error 43.666667 %
# epoch 900, minibatch 8/8, validation error 44.000000 %
# epoch 901, minibatch 8/8, validation error 43.833333 %
# epoch 902, minibatch 8/8, validation error 43.666667 %
# epoch 903, minibatch 8/8, validation error 43.666667 %
# epoch 904, minibatch 8/8, validation error 43.666667 %
# epoch 905, minibatch 8/8, validation error 43.666667 %
# epoch 906, minibatch 8/8, validation error 44.166667 %
# epoch 907, minibatch 8/8, validation error 44.166667 %
# epoch 908, minibatch 8/8, validation error 44.166667 %
# epoch 909, minibatch 8/8, validation error 44.333333 %
# epoch 910, minibatch 8/8, validation error 43.833333 %
# epoch 911, minibatch 8/8, validation error 44.833333 %
# epoch 912, minibatch 8/8, validation error 45.166667 %
# epoch 913, minibatch 8/8, validation error 44.833333 %
# epoch 914, minibatch 8/8, validation error 45.000000 %
# epoch 915, minibatch 8/8, validation error 45.000000 %
# epoch 916, minibatch 8/8, validation error 45.000000 %
# epoch 917, minibatch 8/8, validation error 45.000000 %
# epoch 918, minibatch 8/8, validation error 45.000000 %
# epoch 919, minibatch 8/8, validation error 45.000000 %
# epoch 920, minibatch 8/8, validation error 45.833333 %
# epoch 921, minibatch 8/8, validation error 46.500000 %
# epoch 922, minibatch 8/8, validation error 49.500000 %
# epoch 923, minibatch 8/8, validation error 50.166667 %
# epoch 924, minibatch 8/8, validation error 50.166667 %
# epoch 925, minibatch 8/8, validation error 50.333333 %
# epoch 926, minibatch 8/8, validation error 50.333333 %
# epoch 927, minibatch 8/8, validation error 50.333333 %
# epoch 928, minibatch 8/8, validation error 50.333333 %
# epoch 929, minibatch 8/8, validation error 50.333333 %
# epoch 930, minibatch 8/8, validation error 50.333333 %
# epoch 931, minibatch 8/8, validation error 50.500000 %
# epoch 932, minibatch 8/8, validation error 50.333333 %
# epoch 933, minibatch 8/8, validation error 50.500000 %
# epoch 934, minibatch 8/8, validation error 50.500000 %
# epoch 935, minibatch 8/8, validation error 50.500000 %
# epoch 936, minibatch 8/8, validation error 50.166667 %
# epoch 937, minibatch 8/8, validation error 50.333333 %
# epoch 938, minibatch 8/8, validation error 49.333333 %
# epoch 939, minibatch 8/8, validation error 49.500000 %
# epoch 940, minibatch 8/8, validation error 49.500000 %
# epoch 941, minibatch 8/8, validation error 49.500000 %
# epoch 942, minibatch 8/8, validation error 49.500000 %
# epoch 943, minibatch 8/8, validation error 49.666667 %
# epoch 944, minibatch 8/8, validation error 49.666667 %
# epoch 945, minibatch 8/8, validation error 49.500000 %
# epoch 946, minibatch 8/8, validation error 49.500000 %
# epoch 947, minibatch 8/8, validation error 49.333333 %
# epoch 948, minibatch 8/8, validation error 49.666667 %
# epoch 949, minibatch 8/8, validation error 46.333333 %
# epoch 950, minibatch 8/8, validation error 45.333333 %
# epoch 951, minibatch 8/8, validation error 45.500000 %
# epoch 952, minibatch 8/8, validation error 43.500000 %
# epoch 953, minibatch 8/8, validation error 45.666667 %
# epoch 954, minibatch 8/8, validation error 45.833333 %
# epoch 955, minibatch 8/8, validation error 45.833333 %
# epoch 956, minibatch 8/8, validation error 45.666667 %
# epoch 957, minibatch 8/8, validation error 45.666667 %
# epoch 958, minibatch 8/8, validation error 45.500000 %
# epoch 959, minibatch 8/8, validation error 45.666667 %
# epoch 960, minibatch 8/8, validation error 45.500000 %
# epoch 961, minibatch 8/8, validation error 45.333333 %
# epoch 962, minibatch 8/8, validation error 45.166667 %
# epoch 963, minibatch 8/8, validation error 45.333333 %
# epoch 964, minibatch 8/8, validation error 45.333333 %
# epoch 965, minibatch 8/8, validation error 45.333333 %
# epoch 966, minibatch 8/8, validation error 45.333333 %
# epoch 967, minibatch 8/8, validation error 45.333333 %
# epoch 968, minibatch 8/8, validation error 45.333333 %
# epoch 969, minibatch 8/8, validation error 44.500000 %
# epoch 970, minibatch 8/8, validation error 45.333333 %
# epoch 971, minibatch 8/8, validation error 45.166667 %
# epoch 972, minibatch 8/8, validation error 44.500000 %
# epoch 973, minibatch 8/8, validation error 44.666667 %
# epoch 974, minibatch 8/8, validation error 44.833333 %
# epoch 975, minibatch 8/8, validation error 44.833333 %
# epoch 976, minibatch 8/8, validation error 45.000000 %
# epoch 977, minibatch 8/8, validation error 44.666667 %
# epoch 978, minibatch 8/8, validation error 44.666667 %
# epoch 979, minibatch 8/8, validation error 44.666667 %
# epoch 980, minibatch 8/8, validation error 44.333333 %
# epoch 981, minibatch 8/8, validation error 44.666667 %
# epoch 982, minibatch 8/8, validation error 44.333333 %
# epoch 983, minibatch 8/8, validation error 44.666667 %
# epoch 984, minibatch 8/8, validation error 43.833333 %
# epoch 985, minibatch 8/8, validation error 44.333333 %
# epoch 986, minibatch 8/8, validation error 44.333333 %
# epoch 987, minibatch 8/8, validation error 43.833333 %
# epoch 988, minibatch 8/8, validation error 43.833333 %
# epoch 989, minibatch 8/8, validation error 44.000000 %
# epoch 990, minibatch 8/8, validation error 44.166667 %
# epoch 991, minibatch 8/8, validation error 44.833333 %
# epoch 992, minibatch 8/8, validation error 44.333333 %
# epoch 993, minibatch 8/8, validation error 45.000000 %
# epoch 994, minibatch 8/8, validation error 44.833333 %
# epoch 995, minibatch 8/8, validation error 45.000000 %
# epoch 996, minibatch 8/8, validation error 45.333333 %
# epoch 997, minibatch 8/8, validation error 45.000000 %
# epoch 998, minibatch 8/8, validation error 45.000000 %
# epoch 999, minibatch 8/8, validation error 44.500000 %
# epoch 1000, minibatch 8/8, validation error 44.333333 %
# Optimization complete with best validation score of 42.500000 %,with test performance 43.833333 %
# The code run for 1000 epochs, with 17.357731 epochs/sec
