# %% [markdown]
# # Very naive deep learning on the vector of surrounding bases
#
# ---
#
# ### Data
#
# Naive feature vectors. The original sequence of validation/test and train data does not overlap! ( but train data points can overlap with train data points, and test-validation can overlap with test-validation data ) This overlapping does not lead to unintentional label leakage!
#
#
#
# ### Notes
#
#
# ---

# %% [markdown]
# Instruct theano to use gpu

# %%
import os
os.environ['THEANO_FLAGS']='floatX=float32,device=gpu'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import subprocess
import time

# %% [markdown]
# ### Load data

# %%
import pandas as pd
import numpy as np
import gc

def load_my_data(fname='/mnt/Data1/ribli/methylation_code/prepare_data/meth_feat_vect.csv'):
    """Load my data from file into np.arrays.
    
    It uses int8 for memory efficiency, and speed. Later the values will be
    used as float64 and int32, but pandas double memory usage during loading, so
    I simply can not load them like that. This way the memory usage is not double but
    1+small.
    I have to use garbage collector, because pandas read_csv leaves garbage around.
    """
    
    #load data
    print "Loading data... "
    x=pd.read_csv(fname,sep='\t',engine='c',dtype=np.int8,header=None)
    #shuffle rows
    #this is not necessary it is juts for safety now
    x=x.reindex(np.random.permutation(x.index)).reset_index(drop=True)

    y=np.array(x.iloc[:,-1])
    x=np.array(x.iloc[:,:-1])
    
    # for some reason not everything is cleaned up
    #when using the pandas read_csv
    gc.collect()
    
    return x,y


def load_data(N_train=8000,N_valid=1000,N_test=1000,length=1000):
    """Load and segment my data into random train,valid,test sets for theano."""
    train_x,train_y=load_my_data(
        '/mnt/Data1/ribli/methylation_code/prepare_data/big_train_feat_vect.csv')
    valid_x,valid_y=load_my_data(
        '/mnt/Data1/ribli/methylation_code/prepare_data/big_train_feat_vect.csv')
    test_x,test_y=load_my_data(
        '/mnt/Data1/ribli/methylation_code/prepare_data/big_train_feat_vect.csv')
    
    #determine the slice of data needed
    if length%2==0:
        start=500-length/2
    else:
        start=500-length/2 - 1
        
    my_train_set_x=theano.shared(np.float32(train_x[:N_train,start:start+length]))
    my_valid_set_x=theano.shared(np.float32(valid_x[:N_valid,start:start+length]))
    my_test_set_x=theano.shared(np.float32(test_x[:N_test,start:start+length]))

    my_train_set_y=theano.shared(np.int32(train_y[:N_train]))
    my_valid_set_y=theano.shared(np.int32(valid_y[:N_valid]))
    my_test_set_y=theano.shared(np.int32(test_y[:N_test]))

    return ((my_train_set_x,my_train_set_y),
            (my_valid_set_x,my_valid_set_y),
            (my_test_set_x,my_test_set_y))

# %% [markdown]
# ### Load modules

# %%
import sys
import timeit

import theano
import theano.tensor as T
from theano.tensor.nnet import conv
from theano.tensor.signal import downsample

import numpy
# Out:
# Using gpu device 0: GeForce GTX 670

# %%
class LogisticRegression(object):
    """Multi-class Logistic Regression Class

    The logistic regression is fully described by a weight matrix :math:`W`
    and bias vector :math:`b`. Classification is done by projecting data
    points onto a set of hyperplanes, the distance to which is used to
    determine a class membership probability.
    """

    def __init__(self, input, n_in, n_out):
        """ Initialize the parameters of the logistic regression

        :type input: theano.tensor.TensorType
        :param input: symbolic variable that describes the input of the
                      architecture (one minibatch)

        :type n_in: int
        :param n_in: number of input units, the dimension of the space in
                     which the datapoints lie

        :type n_out: int
        :param n_out: number of output units, the dimension of the space in
                      which the labels lie

        """
        # start-snippet-1
        # initialize with 0 the weights W as a matrix of shape (n_in, n_out)
        self.W = theano.shared(
            value=numpy.zeros(
                (n_in, n_out),
                dtype=theano.config.floatX
            ),
            name='W',
            borrow=True
        )
        # initialize the biases b as a vector of n_out 0s
        self.b = theano.shared(
            value=numpy.zeros(
                (n_out,),
                dtype=theano.config.floatX
            ),
            name='b',
            borrow=True
        )

        # symbolic expression for computing the matrix of class-membership
        # probabilities
        # Where:
        # W is a matrix where column-k represent the separation hyperplane for
        # class-k
        # x is a matrix where row-j  represents input training sample-j
        # b is a vector where element-k represent the free parameter of
        # hyperplane-k
        self.p_y_given_x = T.nnet.softmax(T.dot(input, self.W) + self.b)

        # symbolic description of how to compute prediction as class whose
        # probability is maximal
        self.y_pred = T.argmax(self.p_y_given_x, axis=1)
        # end-snippet-1

        # parameters of the model
        self.params = [self.W, self.b]

        # keep track of model input
        self.input = input

    def negative_log_likelihood(self, y):
        """Return the mean of the negative log-likelihood of the prediction
        of this model under a given target distribution.

        .. math::

            \frac{1}{|\mathcal{D}|} \mathcal{L} (\theta=\{W,b\}, \mathcal{D}) =
            \frac{1}{|\mathcal{D}|} \sum_{i=0}^{|\mathcal{D}|}
                \log(P(Y=y^{(i)}|x^{(i)}, W,b)) \\
            \ell (\theta=\{W,b\}, \mathcal{D})

        :type y: theano.tensor.TensorType
        :param y: corresponds to a vector that gives for each example the
                  correct label

        Note: we use the mean instead of the sum so that
              the learning rate is less dependent on the batch size
        """
        # start-snippet-2
        # y.shape[0] is (symbolically) the number of rows in y, i.e.,
        # number of examples (call it n) in the minibatch
        # T.arange(y.shape[0]) is a symbolic vector which will contain
        # [0,1,2,... n-1] T.log(self.p_y_given_x) is a matrix of
        # Log-Probabilities (call it LP) with one row per example and
        # one column per class LP[T.arange(y.shape[0]),y] is a vector
        # v containing [LP[0,y[0]], LP[1,y[1]], LP[2,y[2]], ...,
        # LP[n-1,y[n-1]]] and T.mean(LP[T.arange(y.shape[0]),y]) is
        # the mean (across minibatch examples) of the elements in v,
        # i.e., the mean log-likelihood across the minibatch.
        return -T.mean(T.log(self.p_y_given_x)[T.arange(y.shape[0]), y])
        # end-snippet-2

    def errors(self, y):
        """Return a float representing the number of errors in the minibatch
        over the total number of examples of the minibatch ; zero one
        loss over the size of the minibatch

        :type y: theano.tensor.TensorType
        :param y: corresponds to a vector that gives for each example the
                  correct label
        """

        # check if y has same dimension of y_pred
        if y.ndim != self.y_pred.ndim:
            raise TypeError(
                'y should have the same shape as self.y_pred',
                ('y', y.type, 'y_pred', self.y_pred.type)
            )
        # check if y is of the correct datatype
        if y.dtype.startswith('int'):
            # the T.neq operator returns a vector of 0s and 1s, where 1
            # represents a mistake in prediction
            return T.mean(T.neq(self.y_pred, y))
        else:
            raise NotImplementedError()

# %%
class HiddenLayer(object):
    def __init__(self, rng, input, n_in, n_out, W=None, b=None,
                 activation=T.tanh):
        """
        Typical hidden layer of a MLP: units are fully-connected and have
        sigmoidal activation function. Weight matrix W is of shape (n_in,n_out)
        and the bias vector b is of shape (n_out,).

        NOTE : The nonlinearity used here is tanh

        Hidden unit activation is given by: tanh(dot(input,W) + b)

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dmatrix
        :param input: a symbolic tensor of shape (n_examples, n_in)

        :type n_in: int
        :param n_in: dimensionality of input

        :type n_out: int
        :param n_out: number of hidden units

        :type activation: theano.Op or function
        :param activation: Non linearity to be applied in the hidden
                           layer
        """
        self.input = input
        # end-snippet-1

        # `W` is initialized with `W_values` which is uniformely sampled
        # from sqrt(-6./(n_in+n_hidden)) and sqrt(6./(n_in+n_hidden))
        # for tanh activation function
        # the output of uniform if converted using asarray to dtype
        # theano.config.floatX so that the code is runable on GPU
        # Note : optimal initialization of weights is dependent on the
        #        activation function used (among other things).
        #        For example, results presented in [Xavier10] suggest that you
        #        should use 4 times larger initial weights for sigmoid
        #        compared to tanh
        #        We have no info for other function, so we use the same as
        #        tanh.
        if W is None:
            W_values = numpy.asarray(
                rng.uniform(
                    low=-numpy.sqrt(6. / (n_in + n_out)),
                    high=numpy.sqrt(6. / (n_in + n_out)),
                    size=(n_in, n_out)
                ),
                dtype=theano.config.floatX
            )
            if activation == theano.tensor.nnet.sigmoid:
                W_values *= 4

            W = theano.shared(value=W_values, name='W', borrow=True)

        if b is None:
            b_values = numpy.zeros((n_out,), dtype=theano.config.floatX)
            b = theano.shared(value=b_values, name='b', borrow=True)

        self.W = W
        self.b = b

        lin_output = T.dot(input, self.W) + self.b
        self.output = (
            lin_output if activation is None
            else activation(lin_output)
        )
        # parameters of the model
        self.params = [self.W, self.b]

# %% [markdown]
# ### Try to modify the tutorial to work on 1-d data

# %%
class LeNetConvPoolLayer(object):
    """Pool Layer of a convolutional network """

    def __init__(self, rng, input, filter_shape, image_shape, poolsize=(2, 1)):
        """
        Allocate a LeNetConvPoolLayer with shared variable internal parameters.

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dtensor4
        :param input: symbolic image tensor, of shape image_shape

        :type filter_shape: tuple or list of length 4
        :param filter_shape: (number of filters, num input feature maps,
                              filter height, filter width)

        :type image_shape: tuple or list of length 4
        :param image_shape: (batch size, num input feature maps,
                             image height, image width)

        """

        assert image_shape[1] == filter_shape[1]
        self.input = input

        # there are "num input feature maps * filter height * filter width"
        # inputs to each hidden unit
        fan_in = numpy.prod(filter_shape[1:])
        # each unit in the lower layer receives a gradient from:
        # "num output feature maps * filter height * filter width" /
        #   pooling size
        fan_out = (filter_shape[0] * numpy.prod(filter_shape[2:])/
                   numpy.prod(poolsize))
        # initialize weights with random weights
        W_bound = numpy.sqrt(6. / (fan_in + fan_out))
        self.W = theano.shared(
            numpy.asarray(
                rng.uniform(low=-W_bound, high=W_bound, size=filter_shape),
                dtype=theano.config.floatX
            ),
            borrow=True
        )

        # the bias is a 1D tensor -- one bias per output feature map
        b_values = numpy.zeros((filter_shape[0],), dtype=theano.config.floatX)
        self.b = theano.shared(value=b_values, borrow=True)

        # convolve input feature maps with filters
        conv_out = conv.conv2d(
            input=input,
            filters=self.W,
            filter_shape=filter_shape,
            image_shape=image_shape
        )

        # downsample each feature map individually, using maxpooling
        pooled_out = downsample.max_pool_2d(
            input=conv_out,
            ds=poolsize,
            ignore_border=True
        )

        # add the bias term. Since the bias is a vector (1D array), we first
        # reshape it to a tensor of shape (1, n_filters, 1, 1). Each bias will
        # thus be broadcasted across mini-batches and feature map
        # width & height
        self.output = T.tanh(pooled_out + self.b.dimshuffle('x', 0, 'x', 'x'))

        # store parameters of this layer
        self.params = [self.W, self.b]

        # keep track of model input
        self.input = input

# %%
def evaluate_lenet5(learning_rate=0.1, n_epochs=200,
                    nkerns=[20, 50], pool_size=(2,1), window_size=5,
                    batch_size=2000,
                    N_train=8000,N_valid=1000,N_test=1000,
                    n_hid_input=400,n_hid_output=500):
    """ Demonstrates lenet on MNIST dataset

    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
                          gradient)

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer

    :type dataset: string
    :param dataset: path to the dataset used for training /testing (MNIST here)

    :type nkerns: list of ints
    :param nkerns: number of kernels on each layer
    """

    rng = numpy.random.RandomState(23455)

    #dataset
    length=((n_hid_input*pool_size[0])+window_size-1)*pool_size[0]+window_size-1
    datasets = load_data(N_train=N_train,N_valid=N_valid,N_test=N_test,length=length)

    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]

    # compute number of minibatches for training, validation and testing
    n_train_batches = train_set_x.get_value(borrow=True).shape[0]
    n_valid_batches = valid_set_x.get_value(borrow=True).shape[0]
    n_test_batches = test_set_x.get_value(borrow=True).shape[0]
    n_train_batches /= batch_size
    n_valid_batches /= batch_size
    n_test_batches /= batch_size

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch

    # start-snippet-1
    x = T.matrix('x')   # the data is presented as rasterized images
    y = T.ivector('y')  # the labels are presented as 1D vector of
                        # [int] labels

    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print '... building the model'

    # Reshape matrix of rasterized images of shape (batch_size, 28 * 28)
    # to a 4D tensor, compatible with our LeNetConvPoolLayer
    # (28, 28) is the size of MNIST images.
    layer0_input = x.reshape((batch_size, 1,length,1))

    # Construct the first convolutional pooling layer:
    # filtering reduces the image size to (28-5+1 , 28-5+1) = (24, 24)
    # maxpooling reduces this further to (24/2, 24/2) = (12, 12)
    # 4D output tensor is thus of shape (batch_size, nkerns[0], 12, 12)
    layer0 = LeNetConvPoolLayer(
        rng,
        input=layer0_input,
        image_shape=(batch_size, 1, length,1),
        filter_shape=(nkerns[0], 1, window_size, 1),
        poolsize=pool_size
    )

    # Construct the second convolutional pooling layer
    # filtering reduces the image size to (12-5+1, 12-5+1) = (8, 8)
    # maxpooling reduces this further to (8/2, 8/2) = (4, 4)
    # 4D output tensor is thus of shape (batch_size, nkerns[1], 4, 4)
    layer1 = LeNetConvPoolLayer(
        rng,
        input=layer0.output,
        image_shape=(batch_size, nkerns[0], n_hid_input*pool_size[0]+window_size-1,1),
        filter_shape=(nkerns[1], nkerns[0], window_size, 1),
        poolsize=pool_size
    )

    # the HiddenLayer being fully-connected, it operates on 2D matrices of
    # shape (batch_size, num_pixels) (i.e matrix of rasterized images).
    # This will generate a matrix of shape (batch_size, nkerns[1] * 4 * 4),
    # or (500, 50 * 4 * 4) = (500, 800) with the default values.
    layer2_input = layer1.output.flatten(2)

    # construct a fully-connected sigmoidal layer
    layer2 = HiddenLayer(
        rng,
        input=layer2_input,
        n_in=nkerns[1] * 1 * n_hid_input,
        n_out=n_hid_output, 
        activation=T.tanh
    )

    # classify the values of the fully-connected sigmoidal layer
    layer3 = LogisticRegression(input=layer2.output, n_in=n_hid_output, n_out=2)

    # the cost we minimize during training is the NLL of the model
    cost = layer3.negative_log_likelihood(y)

    # create a function to compute the mistakes that are made by the model
    test_model = theano.function(
        [index],
        layer3.errors(y),
        givens={
            x: test_set_x[index * batch_size: (index + 1) * batch_size],
            y: test_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    validate_model = theano.function(
        [index],
        layer3.errors(y),
        givens={
            x: valid_set_x[index * batch_size: (index + 1) * batch_size],
            y: valid_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )
    
    check_model_on_training = theano.function(
        [index],
        layer3.errors(y),
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    # create a list of all model parameters to be fit by gradient descent
    params = layer3.params + layer2.params + layer1.params + layer0.params

    # create a list of gradients for all model parameters
    grads = T.grad(cost, params)

    # train_model is a function that updates the model parameters by
    # SGD Since this model has many parameters, it would be tedious to
    # manually create an update rule for each model parameter. We thus
    # create the updates list by automatically looping over all
    # (params[i], grads[i]) pairs.
    updates = [
        (param_i, param_i - learning_rate * grad_i)
        for param_i, grad_i in zip(params, grads)
    ]

    train_model = theano.function(
        [index],
        cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )
    # end-snippet-1

    
    
    
    
    
    ###############
    # TRAIN MODEL #
    ###############
    print '... training'
    # early-stopping parameters
    patience = 50000  # look as this many examples regardless
    patience_increase = 4  # wait this much longer when a new best is
                           # found
    improvement_threshold = 0.995  # a relative improvement of this much is
                                   # considered significant
    validation_frequency = min(n_train_batches, patience / 2)
                                  # go through this many
                                  # minibatche before checking the network
                                  # on the validation set; in this case we
                                  # check every epoch

    best_validation_loss = numpy.inf
    best_iter = 0
    test_score = 0.
    start_time = timeit.default_timer()

    epoch = 0
    done_looping = False

    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in xrange(n_train_batches):

            iter = (epoch - 1) * n_train_batches + minibatch_index

            if iter % 10000 == 0:
                print 'training @ iter = ', iter
            cost_ij = train_model(minibatch_index)

            if (iter + 1) % validation_frequency == 0:

                # compute zero-one loss on train set
                train_losses = [check_model_on_training(i) for i
                                     in xrange(n_train_batches)]
                this_train_loss = numpy.mean(train_losses)
                print('epoch %i, minibatch %i/%i, training error %f %%' %
                      (epoch, minibatch_index + 1, n_train_batches,
                       this_train_loss * 100.)),
                
                # compute zero-one loss on validation set
                validation_losses = [validate_model(i) for i
                                     in xrange(n_valid_batches)]
                this_validation_loss = numpy.mean(validation_losses)
                #print('epoch %i, minibatch %i/%i, validation error %f %%' %\
                # (epoch, minibatch_index + 1, n_train_batches,
                #       this_validation_loss * 100.))
                print(' , validation error %f %%' %
                       (this_validation_loss * 100.))

                # if we got the best validation score until now
                if this_validation_loss < best_validation_loss:

                    #improve patience if loss improvement is good enough
                    if this_validation_loss < best_validation_loss *  \
                       improvement_threshold:
                        patience = max(patience, iter * patience_increase)

                    # save best validation score and iteration number
                    best_validation_loss = this_validation_loss
                    best_iter = iter

                    # test it on the test set
                    test_losses = [
                        test_model(i)
                        for i in xrange(n_test_batches)
                    ]
                    test_score = numpy.mean(test_losses)
                    print(('     epoch %i, minibatch %i/%i, test error of '
                           'best model %f %%') %
                          (epoch, minibatch_index + 1, n_train_batches,
                           test_score * 100.))

            if patience <= iter:
                done_looping = True
                break

    end_time = timeit.default_timer()
    print('Optimization complete.')
    print('Best validation score of %f %% obtained at iteration %i, '
          'with test performance %f %%' %
          (best_validation_loss * 100., best_iter + 1, test_score * 100.))
    print 'The code run for %d epochs, with %f epochs/sec' % (
        epoch, 1. * epoch / (end_time - start_time))

# %%
evaluate_lenet5(learning_rate=0.05,
                batch_size=500,
                nkerns=[20, 50], #number of feature maps
                pool_size=(8,1), # max pooling reduction factor(s)
                n_hid_input=15, # number of hidden layer inputs, -> radius
                n_hid_output=50, # hidden layer number of neurons
                window_size=5, # convolution window size
                n_epochs=1000, # learning length
                N_train=119000,N_valid=10000,N_test=10000) # learning data size
# Out:
# Loading data...
# Loading data...
# Loading data...
# ... building the model
# ... training
# training @ iter =  0
# epoch 1, minibatch 238/238, training error 30.175630 %  , validation error 29.360000 %
#      epoch 1, minibatch 238/238, test error of best model 31.040000 %
# epoch 2, minibatch 238/238, training error 26.696639 %  , validation error 25.960000 %
#      epoch 2, minibatch 238/238, test error of best model 27.200000 %
# epoch 3, minibatch 238/238, training error 25.605042 %  , validation error 25.510000 %
#      epoch 3, minibatch 238/238, test error of best model 25.850000 %
# epoch 4, minibatch 238/238, training error 27.845378 %  , validation error 28.110000 %
# epoch 5, minibatch 238/238, training error 22.219328 %  , validation error 21.900000 %
#      epoch 5, minibatch 238/238, test error of best model 22.900000 %
# epoch 6, minibatch 238/238, training error 21.875630 %  , validation error 21.510000 %
#      epoch 6, minibatch 238/238, test error of best model 22.600000 %
# epoch 7, minibatch 238/238, training error 22.535294 %  , validation error 22.170000 %
# epoch 8, minibatch 238/238, training error 20.336134 %  , validation error 20.020000 %
#      epoch 8, minibatch 238/238, test error of best model 21.030000 %
# epoch 9, minibatch 238/238, training error 23.836975 %  , validation error 23.490000 %
# epoch 10, minibatch 238/238, training error 23.257143 %  , validation error 22.980000 %
# epoch 11, minibatch 238/238, training error 22.685714 %  , validation error 22.370000 %
# epoch 12, minibatch 238/238, training error 22.167227 %  , validation error 21.870000 %
# epoch 13, minibatch 238/238, training error 21.766387 %  , validation error 21.520000 %
# epoch 14, minibatch 238/238, training error 21.408403 %  , validation error 21.110000 %
# epoch 15, minibatch 238/238, training error 21.119328 %  , validation error 20.900000 %
# epoch 16, minibatch 238/238, training error 20.950420 %  , validation error 20.690000 %
# epoch 17, minibatch 238/238, training error 20.725210 %  , validation error 20.500000 %
# epoch 18, minibatch 238/238, training error 20.531092 %  , validation error 20.200000 %
# epoch 19, minibatch 238/238, training error 20.272269 %  , validation error 19.920000 %
#      epoch 19, minibatch 238/238, test error of best model 20.610000 %
# epoch 20, minibatch 238/238, training error 19.957983 %  , validation error 19.630000 %
#      epoch 20, minibatch 238/238, test error of best model 20.340000 %
# epoch 21, minibatch 238/238, training error 19.717647 %  , validation error 19.490000 %
#      epoch 21, minibatch 238/238, test error of best model 20.100000 %
# epoch 22, minibatch 238/238, training error 19.452941 %  , validation error 19.200000 %
#      epoch 22, minibatch 238/238, test error of best model 19.820000 %
# epoch 23, minibatch 238/238, training error 19.263025 %  , validation error 19.060000 %
#      epoch 23, minibatch 238/238, test error of best model 19.650000 %
# epoch 24, minibatch 238/238, training error 19.054622 %  , validation error 18.850000 %
#      epoch 24, minibatch 238/238, test error of best model 19.390000 %
# epoch 25, minibatch 238/238, training error 18.883193 %  , validation error 18.710000 %
#      epoch 25, minibatch 238/238, test error of best model 19.190000 %
# epoch 26, minibatch 238/238, training error 18.723529 %  , validation error 18.590000 %
#      epoch 26, minibatch 238/238, test error of best model 19.010000 %
# epoch 27, minibatch 238/238, training error 18.596639 %  , validation error 18.550000 %
#      epoch 27, minibatch 238/238, test error of best model 18.910000 %
# epoch 28, minibatch 238/238, training error 18.475630 %  , validation error 18.420000 %
#      epoch 28, minibatch 238/238, test error of best model 18.790000 %
# epoch 29, minibatch 238/238, training error 18.350420 %  , validation error 18.300000 %
#      epoch 29, minibatch 238/238, test error of best model 18.630000 %
# epoch 30, minibatch 238/238, training error 18.192437 %  , validation error 18.090000 %
#      epoch 30, minibatch 238/238, test error of best model 18.430000 %
# epoch 31, minibatch 238/238, training error 18.038655 %  , validation error 17.920000 %
#      epoch 31, minibatch 238/238, test error of best model 18.340000 %
# epoch 32, minibatch 238/238, training error 17.844538 %  , validation error 17.770000 %
#      epoch 32, minibatch 238/238, test error of best model 18.160000 %
# epoch 33, minibatch 238/238, training error 17.700840 %  , validation error 17.660000 %
#      epoch 33, minibatch 238/238, test error of best model 17.980000 %
# epoch 34, minibatch 238/238, training error 17.561345 %  , validation error 17.540000 %
#      epoch 34, minibatch 238/238, test error of best model 17.860000 %
# epoch 35, minibatch 238/238, training error 17.394958 %  , validation error 17.320000 %
#      epoch 35, minibatch 238/238, test error of best model 17.630000 %
# epoch 36, minibatch 238/238, training error 17.219328 %  , validation error 17.190000 %
#      epoch 36, minibatch 238/238, test error of best model 17.410000 %
# epoch 37, minibatch 238/238, training error 17.041176 %  , validation error 17.000000 %
#      epoch 37, minibatch 238/238, test error of best model 17.340000 %
# epoch 38, minibatch 238/238, training error 16.871429 %  , validation error 16.810000 %
#      epoch 38, minibatch 238/238, test error of best model 17.070000 %
# epoch 39, minibatch 238/238, training error 16.700840 %  , validation error 16.660000 %
#      epoch 39, minibatch 238/238, test error of best model 16.910000 %
# epoch 40, minibatch 238/238, training error 16.531092 %  , validation error 16.500000 %
#      epoch 40, minibatch 238/238, test error of best model 16.760000 %
# epoch 41, minibatch 238/238, training error 16.370588 %  , validation error 16.240000 %
#      epoch 41, minibatch 238/238, test error of best model 16.490000 %
# epoch 42, minibatch 238/238, training error 16.225210 %  , validation error 16.200000 %
#      epoch 42, minibatch 238/238, test error of best model 16.390000 %
# training @ iter =  10000
# epoch 43, minibatch 238/238, training error 16.105882 %  , validation error 16.190000 %
#      epoch 43, minibatch 238/238, test error of best model 16.280000 %
# epoch 44, minibatch 238/238, training error 15.999160 %  , validation error 16.080000 %
#      epoch 44, minibatch 238/238, test error of best model 16.140000 %
# epoch 45, minibatch 238/238, training error 15.859664 %  , validation error 16.050000 %
#      epoch 45, minibatch 238/238, test error of best model 16.060000 %
# epoch 46, minibatch 238/238, training error 15.691597 %  , validation error 15.990000 %
#      epoch 46, minibatch 238/238, test error of best model 15.970000 %
# epoch 47, minibatch 238/238, training error 15.540336 %  , validation error 15.910000 %
#      epoch 47, minibatch 238/238, test error of best model 15.750000 %
# epoch 48, minibatch 238/238, training error 15.463866 %  , validation error 15.840000 %
#      epoch 48, minibatch 238/238, test error of best model 15.720000 %
# epoch 49, minibatch 238/238, training error 15.323529 %  , validation error 15.760000 %
#      epoch 49, minibatch 238/238, test error of best model 15.610000 %
# epoch 50, minibatch 238/238, training error 15.256303 %  , validation error 15.690000 %
#      epoch 50, minibatch 238/238, test error of best model 15.480000 %
# epoch 51, minibatch 238/238, training error 15.183193 %  , validation error 15.660000 %
#      epoch 51, minibatch 238/238, test error of best model 15.430000 %
# epoch 52, minibatch 238/238, training error 15.128571 %  , validation error 15.550000 %
#      epoch 52, minibatch 238/238, test error of best model 15.360000 %
# epoch 53, minibatch 238/238, training error 15.159664 %  , validation error 15.410000 %
#      epoch 53, minibatch 238/238, test error of best model 15.380000 %
# epoch 54, minibatch 238/238, training error 14.994958 %  , validation error 15.430000 %
# epoch 55, minibatch 238/238, training error 14.980672 %  , validation error 15.360000 %
#      epoch 55, minibatch 238/238, test error of best model 15.210000 %
# epoch 56, minibatch 238/238, training error 15.057983 %  , validation error 15.560000 %
# epoch 57, minibatch 238/238, training error 14.748739 %  , validation error 15.200000 %
#      epoch 57, minibatch 238/238, test error of best model 14.930000 %
# epoch 58, minibatch 238/238, training error 14.751261 %  , validation error 15.270000 %
# epoch 59, minibatch 238/238, training error 14.624370 %  , validation error 15.170000 %
#      epoch 59, minibatch 238/238, test error of best model 14.700000 %
# epoch 60, minibatch 238/238, training error 14.644538 %  , validation error 15.230000 %
# epoch 61, minibatch 238/238, training error 14.940336 %  , validation error 15.420000 %
# epoch 62, minibatch 238/238, training error 14.447899 %  , validation error 14.930000 %
#      epoch 62, minibatch 238/238, test error of best model 14.640000 %
# epoch 63, minibatch 238/238, training error 15.641176 %  , validation error 15.790000 %
# epoch 64, minibatch 238/238, training error 15.085714 %  , validation error 15.490000 %
# epoch 65, minibatch 238/238, training error 14.982353 %  , validation error 15.430000 %
# epoch 66, minibatch 238/238, training error 14.951261 %  , validation error 15.390000 %
# epoch 67, minibatch 238/238, training error 14.797479 %  , validation error 15.250000 %
# epoch 68, minibatch 238/238, training error 14.635294 %  , validation error 15.140000 %
# epoch 69, minibatch 238/238, training error 14.589916 %  , validation error 15.150000 %
# epoch 70, minibatch 238/238, training error 18.487395 %  , validation error 18.680000 %
# epoch 71, minibatch 238/238, training error 14.231933 %  , validation error 14.770000 %
#      epoch 71, minibatch 238/238, test error of best model 14.280000 %
# epoch 72, minibatch 238/238, training error 15.889916 %  , validation error 16.100000 %
# epoch 73, minibatch 238/238, training error 15.263025 %  , validation error 15.630000 %
# epoch 74, minibatch 238/238, training error 13.931092 %  , validation error 14.480000 %
#      epoch 74, minibatch 238/238, test error of best model 13.940000 %
# epoch 75, minibatch 238/238, training error 13.869748 %  , validation error 14.390000 %
#      epoch 75, minibatch 238/238, test error of best model 13.790000 %
# epoch 76, minibatch 238/238, training error 13.841176 %  , validation error 14.410000 %
# epoch 77, minibatch 238/238, training error 13.627731 %  , validation error 14.150000 %
#      epoch 77, minibatch 238/238, test error of best model 13.620000 %
# epoch 78, minibatch 238/238, training error 15.386555 %  , validation error 15.900000 %
# epoch 79, minibatch 238/238, training error 16.762185 %  , validation error 17.170000 %
# epoch 80, minibatch 238/238, training error 14.678992 %  , validation error 15.010000 %
# epoch 81, minibatch 238/238, training error 13.800840 %  , validation error 14.560000 %
# epoch 82, minibatch 238/238, training error 13.674790 %  , validation error 14.300000 %
# epoch 83, minibatch 238/238, training error 13.625210 %  , validation error 14.200000 %
# epoch 84, minibatch 238/238, training error 13.520168 %  , validation error 14.030000 %
#      epoch 84, minibatch 238/238, test error of best model 13.410000 %
# training @ iter =  20000
# epoch 85, minibatch 238/238, training error 13.467227 %  , validation error 14.070000 %
# epoch 86, minibatch 238/238, training error 13.405042 %  , validation error 14.010000 %
#      epoch 86, minibatch 238/238, test error of best model 13.330000 %
# epoch 87, minibatch 238/238, training error 13.285714 %  , validation error 13.820000 %
#      epoch 87, minibatch 238/238, test error of best model 13.590000 %
# epoch 88, minibatch 238/238, training error 13.315126 %  , validation error 13.820000 %
# epoch 89, minibatch 238/238, training error 13.275630 %  , validation error 13.740000 %
#      epoch 89, minibatch 238/238, test error of best model 13.140000 %
# epoch 90, minibatch 238/238, training error 13.130252 %  , validation error 13.690000 %
#      epoch 90, minibatch 238/238, test error of best model 13.250000 %
# epoch 91, minibatch 238/238, training error 13.398319 %  , validation error 14.020000 %
# epoch 92, minibatch 238/238, training error 13.347899 %  , validation error 13.950000 %
# epoch 93, minibatch 238/238, training error 15.796639 %  , validation error 16.270000 %
# epoch 94, minibatch 238/238, training error 14.363866 %  , validation error 14.810000 %
# epoch 95, minibatch 238/238, training error 13.266387 %  , validation error 13.610000 %
#      epoch 95, minibatch 238/238, test error of best model 13.550000 %
# epoch 96, minibatch 238/238, training error 13.101681 %  , validation error 13.670000 %
# epoch 97, minibatch 238/238, training error 12.896639 %  , validation error 13.440000 %
#      epoch 97, minibatch 238/238, test error of best model 13.050000 %
# epoch 98, minibatch 238/238, training error 12.876471 %  , validation error 13.360000 %
#      epoch 98, minibatch 238/238, test error of best model 13.000000 %
# epoch 99, minibatch 238/238, training error 13.966387 %  , validation error 14.100000 %
# epoch 100, minibatch 238/238, training error 13.006723 %  , validation error 13.280000 %
#      epoch 100, minibatch 238/238, test error of best model 13.170000 %
# epoch 101, minibatch 238/238, training error 12.889916 %  , validation error 13.500000 %
# epoch 102, minibatch 238/238, training error 14.263025 %  , validation error 14.560000 %
# epoch 103, minibatch 238/238, training error 12.889076 %  , validation error 13.500000 %
# epoch 104, minibatch 238/238, training error 12.689076 %  , validation error 13.170000 %
#      epoch 104, minibatch 238/238, test error of best model 12.470000 %
# epoch 105, minibatch 238/238, training error 13.252941 %  , validation error 13.850000 %
# epoch 106, minibatch 238/238, training error 13.367227 %  , validation error 13.620000 %
# epoch 107, minibatch 238/238, training error 13.879832 %  , validation error 14.170000 %
# epoch 108, minibatch 238/238, training error 13.241176 %  , validation error 13.860000 %
# epoch 109, minibatch 238/238, training error 12.493277 %  , validation error 13.000000 %
#      epoch 109, minibatch 238/238, test error of best model 12.260000 %
# epoch 110, minibatch 238/238, training error 12.671429 %  , validation error 12.960000 %
#      epoch 110, minibatch 238/238, test error of best model 12.870000 %
# epoch 111, minibatch 238/238, training error 13.717647 %  , validation error 14.030000 %
# epoch 112, minibatch 238/238, training error 12.402521 %  , validation error 12.850000 %
#      epoch 112, minibatch 238/238, test error of best model 12.070000 %
# epoch 113, minibatch 238/238, training error 12.157143 %  , validation error 12.470000 %
#      epoch 113, minibatch 238/238, test error of best model 11.980000 %
# epoch 114, minibatch 238/238, training error 13.150420 %  , validation error 13.420000 %
# epoch 115, minibatch 238/238, training error 12.101681 %  , validation error 12.420000 %
#      epoch 115, minibatch 238/238, test error of best model 11.930000 %
# epoch 116, minibatch 238/238, training error 12.989916 %  , validation error 13.550000 %
# epoch 117, minibatch 238/238, training error 12.092437 %  , validation error 12.380000 %
#      epoch 117, minibatch 238/238, test error of best model 12.000000 %
# epoch 118, minibatch 238/238, training error 11.978992 %  , validation error 12.380000 %
#      epoch 118, minibatch 238/238, test error of best model 11.890000 %
# epoch 119, minibatch 238/238, training error 14.208403 %  , validation error 14.470000 %
# epoch 120, minibatch 238/238, training error 12.705882 %  , validation error 13.170000 %
# epoch 121, minibatch 238/238, training error 12.522689 %  , validation error 12.760000 %
# epoch 122, minibatch 238/238, training error 14.620168 %  , validation error 14.960000 %
# epoch 123, minibatch 238/238, training error 12.163025 %  , validation error 12.470000 %
# epoch 124, minibatch 238/238, training error 12.163025 %  , validation error 12.480000 %
# epoch 125, minibatch 238/238, training error 12.422689 %  , validation error 12.590000 %
# epoch 126, minibatch 238/238, training error 12.136975 %  , validation error 12.470000 %
# training @ iter =  30000
# epoch 127, minibatch 238/238, training error 13.241176 %  , validation error 13.360000 %
# epoch 128, minibatch 238/238, training error 11.548739 %  , validation error 11.910000 %
#      epoch 128, minibatch 238/238, test error of best model 11.260000 %
# epoch 129, minibatch 238/238, training error 14.376471 %  , validation error 14.730000 %
# epoch 130, minibatch 238/238, training error 11.518487 %  , validation error 11.770000 %
#      epoch 130, minibatch 238/238, test error of best model 11.590000 %
# epoch 131, minibatch 238/238, training error 12.024370 %  , validation error 12.310000 %
# epoch 132, minibatch 238/238, training error 14.704202 %  , validation error 14.900000 %
# epoch 133, minibatch 238/238, training error 12.881513 %  , validation error 13.170000 %
# epoch 134, minibatch 238/238, training error 11.389916 %  , validation error 11.760000 %
#      epoch 134, minibatch 238/238, test error of best model 11.130000 %
# epoch 135, minibatch 238/238, training error 11.521008 %  , validation error 11.840000 %
# epoch 136, minibatch 238/238, training error 12.382353 %  , validation error 12.600000 %
# epoch 137, minibatch 238/238, training error 13.352101 %  , validation error 13.600000 %
# epoch 138, minibatch 238/238, training error 11.479832 %  , validation error 11.790000 %
# epoch 139, minibatch 238/238, training error 12.874790 %  , validation error 13.130000 %
# epoch 140, minibatch 238/238, training error 12.063866 %  , validation error 12.460000 %
# epoch 141, minibatch 238/238, training error 10.940336 %  , validation error 11.400000 %
#      epoch 141, minibatch 238/238, test error of best model 10.850000 %
# epoch 142, minibatch 238/238, training error 12.826050 %  , validation error 13.040000 %
# epoch 143, minibatch 238/238, training error 10.891597 %  , validation error 11.410000 %
# epoch 144, minibatch 238/238, training error 10.933613 %  , validation error 11.280000 %
#      epoch 144, minibatch 238/238, test error of best model 10.950000 %
# epoch 145, minibatch 238/238, training error 11.544538 %  , validation error 11.890000 %
# epoch 146, minibatch 238/238, training error 10.703361 %  , validation error 11.250000 %
#      epoch 146, minibatch 238/238, test error of best model 10.500000 %
# epoch 147, minibatch 238/238, training error 11.884874 %  , validation error 12.180000 %
# epoch 148, minibatch 238/238, training error 12.189916 %  , validation error 12.360000 %
# epoch 149, minibatch 238/238, training error 10.678151 %  , validation error 11.130000 %
#      epoch 149, minibatch 238/238, test error of best model 10.660000 %
# epoch 150, minibatch 238/238, training error 10.492437 %  , validation error 11.080000 %
#      epoch 150, minibatch 238/238, test error of best model 10.310000 %
# epoch 151, minibatch 238/238, training error 10.505882 %  , validation error 11.060000 %
#      epoch 151, minibatch 238/238, test error of best model 10.340000 %
# epoch 152, minibatch 238/238, training error 10.414286 %  , validation error 10.960000 %
#      epoch 152, minibatch 238/238, test error of best model 10.180000 %
# epoch 153, minibatch 238/238, training error 11.735294 %  , validation error 12.060000 %
# epoch 154, minibatch 238/238, training error 10.295798 %  , validation error 10.910000 %
#      epoch 154, minibatch 238/238, test error of best model 10.040000 %
# epoch 155, minibatch 238/238, training error 11.557983 %  , validation error 11.890000 %
# epoch 156, minibatch 238/238, training error 10.185714 %  , validation error 10.640000 %
#      epoch 156, minibatch 238/238, test error of best model 10.000000 %
# epoch 157, minibatch 238/238, training error 11.524370 %  , validation error 11.900000 %
# epoch 158, minibatch 238/238, training error 10.103361 %  , validation error 10.600000 %
#      epoch 158, minibatch 238/238, test error of best model 10.020000 %
# epoch 159, minibatch 238/238, training error 11.436975 %  , validation error 11.920000 %
# epoch 160, minibatch 238/238, training error 10.342857 %  , validation error 10.790000 %
# epoch 161, minibatch 238/238, training error 9.976471 %  , validation error 10.380000 %
#      epoch 161, minibatch 238/238, test error of best model 9.810000 %
# epoch 162, minibatch 238/238, training error 10.773950 %  , validation error 11.160000 %
# epoch 163, minibatch 238/238, training error 9.855462 %  , validation error 10.210000 %
#      epoch 163, minibatch 238/238, test error of best model 9.790000 %
# epoch 164, minibatch 238/238, training error 10.718487 %  , validation error 11.130000 %
# epoch 165, minibatch 238/238, training error 10.176471 %  , validation error 10.630000 %
# epoch 166, minibatch 238/238, training error 9.676471 %  , validation error 10.160000 %
#      epoch 166, minibatch 238/238, test error of best model 9.650000 %
# epoch 167, minibatch 238/238, training error 9.587395 %  , validation error 9.990000 %
#      epoch 167, minibatch 238/238, test error of best model 9.610000 %
# epoch 168, minibatch 238/238, training error 10.884034 %  , validation error 11.470000 %
# training @ iter =  40000
# epoch 169, minibatch 238/238, training error 9.981513 %  , validation error 10.450000 %
# epoch 170, minibatch 238/238, training error 9.533613 %  , validation error 9.810000 %
#      epoch 170, minibatch 238/238, test error of best model 9.540000 %
# epoch 171, minibatch 238/238, training error 9.400840 %  , validation error 9.750000 %
#      epoch 171, minibatch 238/238, test error of best model 9.330000 %
# epoch 172, minibatch 238/238, training error 10.971429 %  , validation error 11.550000 %
# epoch 173, minibatch 238/238, training error 9.755462 %  , validation error 10.120000 %
# epoch 174, minibatch 238/238, training error 9.228571 %  , validation error 9.580000 %
#      epoch 174, minibatch 238/238, test error of best model 9.090000 %
# epoch 175, minibatch 238/238, training error 9.105882 %  , validation error 9.530000 %
#      epoch 175, minibatch 238/238, test error of best model 8.960000 %
# epoch 176, minibatch 238/238, training error 10.167227 %  , validation error 10.460000 %
# epoch 177, minibatch 238/238, training error 9.825210 %  , validation error 10.140000 %
# epoch 178, minibatch 238/238, training error 8.907563 %  , validation error 9.220000 %
#      epoch 178, minibatch 238/238, test error of best model 8.720000 %
# epoch 179, minibatch 238/238, training error 10.152101 %  , validation error 10.530000 %
# epoch 180, minibatch 238/238, training error 8.942017 %  , validation error 9.260000 %
# epoch 181, minibatch 238/238, training error 9.278992 %  , validation error 9.560000 %
# epoch 182, minibatch 238/238, training error 9.002521 %  , validation error 9.390000 %
# epoch 183, minibatch 238/238, training error 9.396639 %  , validation error 9.780000 %
# epoch 184, minibatch 238/238, training error 9.104202 %  , validation error 9.260000 %
# epoch 185, minibatch 238/238, training error 8.508403 %  , validation error 8.910000 %
#      epoch 185, minibatch 238/238, test error of best model 8.220000 %
# epoch 186, minibatch 238/238, training error 8.436134 %  , validation error 8.760000 %
#      epoch 186, minibatch 238/238, test error of best model 8.280000 %
# epoch 187, minibatch 238/238, training error 8.676471 %  , validation error 8.940000 %
# epoch 188, minibatch 238/238, training error 8.217647 %  , validation error 8.600000 %
#      epoch 188, minibatch 238/238, test error of best model 7.880000 %
# epoch 189, minibatch 238/238, training error 9.544538 %  , validation error 9.840000 %
# epoch 190, minibatch 238/238, training error 8.444538 %  , validation error 8.970000 %
# epoch 191, minibatch 238/238, training error 8.002521 %  , validation error 8.370000 %
#      epoch 191, minibatch 238/238, test error of best model 7.760000 %
# epoch 192, minibatch 238/238, training error 8.159664 %  , validation error 8.590000 %
# epoch 193, minibatch 238/238, training error 7.848739 %  , validation error 8.150000 %
#      epoch 193, minibatch 238/238, test error of best model 7.680000 %
# epoch 194, minibatch 238/238, training error 7.937815 %  , validation error 8.260000 %
# epoch 195, minibatch 238/238, training error 7.741176 %  , validation error 8.180000 %
# epoch 196, minibatch 238/238, training error 12.384034 %  , validation error 12.780000 %
# epoch 197, minibatch 238/238, training error 7.622689 %  , validation error 7.890000 %
#      epoch 197, minibatch 238/238, test error of best model 7.500000 %
# epoch 198, minibatch 238/238, training error 9.562185 %  , validation error 9.880000 %
# epoch 199, minibatch 238/238, training error 7.515966 %  , validation error 7.870000 %
#      epoch 199, minibatch 238/238, test error of best model 7.250000 %
# epoch 200, minibatch 238/238, training error 7.433613 %  , validation error 7.790000 %
#      epoch 200, minibatch 238/238, test error of best model 7.230000 %
# epoch 201, minibatch 238/238, training error 7.347899 %  , validation error 7.670000 %
#      epoch 201, minibatch 238/238, test error of best model 7.150000 %
# epoch 202, minibatch 238/238, training error 7.300000 %  , validation error 7.650000 %
#      epoch 202, minibatch 238/238, test error of best model 7.170000 %
# epoch 203, minibatch 238/238, training error 7.184874 %  , validation error 7.510000 %
#      epoch 203, minibatch 238/238, test error of best model 6.790000 %
# epoch 204, minibatch 238/238, training error 7.215126 %  , validation error 7.580000 %
# epoch 205, minibatch 238/238, training error 7.095798 %  , validation error 7.410000 %
#      epoch 205, minibatch 238/238, test error of best model 6.820000 %
# epoch 206, minibatch 238/238, training error 7.830252 %  , validation error 7.990000 %
# epoch 207, minibatch 238/238, training error 7.398319 %  , validation error 7.660000 %
# epoch 208, minibatch 238/238, training error 6.897479 %  , validation error 7.300000 %
#      epoch 208, minibatch 238/238, test error of best model 6.890000 %
# epoch 209, minibatch 238/238, training error 7.447059 %  , validation error 7.780000 %
# epoch 210, minibatch 238/238, training error 6.675630 %  , validation error 7.070000 %
#      epoch 210, minibatch 238/238, test error of best model 6.680000 %
# training @ iter =  50000
# epoch 211, minibatch 238/238, training error 9.100000 %  , validation error 9.380000 %
# epoch 212, minibatch 238/238, training error 8.131092 %  , validation error 8.390000 %
# epoch 213, minibatch 238/238, training error 6.549580 %  , validation error 6.850000 %
#      epoch 213, minibatch 238/238, test error of best model 6.580000 %
# epoch 214, minibatch 238/238, training error 6.970588 %  , validation error 7.260000 %
# epoch 215, minibatch 238/238, training error 6.755462 %  , validation error 6.990000 %
# epoch 216, minibatch 238/238, training error 7.357143 %  , validation error 7.530000 %
# epoch 217, minibatch 238/238, training error 6.369748 %  , validation error 6.730000 %
#      epoch 217, minibatch 238/238, test error of best model 6.450000 %
# epoch 218, minibatch 238/238, training error 7.089916 %  , validation error 7.290000 %
# epoch 219, minibatch 238/238, training error 6.199160 %  , validation error 6.570000 %
#      epoch 219, minibatch 238/238, test error of best model 6.210000 %
# epoch 220, minibatch 238/238, training error 6.531092 %  , validation error 6.760000 %
# epoch 221, minibatch 238/238, training error 6.300000 %  , validation error 6.590000 %
# epoch 222, minibatch 238/238, training error 6.533613 %  , validation error 6.830000 %
# epoch 223, minibatch 238/238, training error 6.180672 %  , validation error 6.440000 %
#      epoch 223, minibatch 238/238, test error of best model 6.190000 %
# epoch 224, minibatch 238/238, training error 7.140336 %  , validation error 7.350000 %
# epoch 225, minibatch 238/238, training error 5.670588 %  , validation error 5.910000 %
#      epoch 225, minibatch 238/238, test error of best model 5.570000 %
# epoch 226, minibatch 238/238, training error 6.113445 %  , validation error 6.280000 %
# epoch 227, minibatch 238/238, training error 7.126891 %  , validation error 7.440000 %
# epoch 228, minibatch 238/238, training error 7.847899 %  , validation error 8.230000 %
# epoch 229, minibatch 238/238, training error 9.349580 %  , validation error 9.380000 %
# epoch 230, minibatch 238/238, training error 5.492437 %  , validation error 5.640000 %
#      epoch 230, minibatch 238/238, test error of best model 5.570000 %
# epoch 231, minibatch 238/238, training error 10.836975 %  , validation error 10.840000 %
# epoch 232, minibatch 238/238, training error 6.299160 %  , validation error 6.520000 %
# epoch 233, minibatch 238/238, training error 10.486555 %  , validation error 10.580000 %
# epoch 234, minibatch 238/238, training error 5.304202 %  , validation error 5.480000 %
#      epoch 234, minibatch 238/238, test error of best model 5.280000 %
# epoch 235, minibatch 238/238, training error 7.452101 %  , validation error 7.550000 %
# epoch 236, minibatch 238/238, training error 16.921849 %  , validation error 17.430000 %
# epoch 237, minibatch 238/238, training error 21.651261 %  , validation error 21.930000 %
# epoch 238, minibatch 238/238, training error 20.845378 %  , validation error 20.600000 %
# epoch 239, minibatch 238/238, training error 22.437815 %  , validation error 22.240000 %
# epoch 240, minibatch 238/238, training error 18.241176 %  , validation error 18.180000 %
# epoch 241, minibatch 238/238, training error 17.207563 %  , validation error 17.140000 %
# epoch 242, minibatch 238/238, training error 16.928571 %  , validation error 16.910000 %
# epoch 243, minibatch 238/238, training error 17.726891 %  , validation error 17.430000 %
# epoch 244, minibatch 238/238, training error 17.650420 %  , validation error 17.240000 %
# epoch 245, minibatch 238/238, training error 16.906723 %  , validation error 16.770000 %
# epoch 246, minibatch 238/238, training error 16.212605 %  , validation error 16.230000 %
# epoch 247, minibatch 238/238, training error 16.379832 %  , validation error 16.320000 %
# epoch 248, minibatch 238/238, training error 16.467227 %  , validation error 16.280000 %
# epoch 249, minibatch 238/238, training error 16.494118 %  , validation error 16.280000 %
# epoch 250, minibatch 238/238, training error 15.558824 %  , validation error 15.580000 %
# epoch 251, minibatch 238/238, training error 15.753782 %  , validation error 15.720000 %
# epoch 252, minibatch 238/238, training error 15.940336 %  , validation error 15.860000 %
# training @ iter =  60000
# epoch 253, minibatch 238/238, training error 14.205882 %  , validation error 14.560000 %
# epoch 254, minibatch 238/238, training error 14.080672 %  , validation error 14.490000 %
# epoch 255, minibatch 238/238, training error 16.015126 %  , validation error 15.710000 %
# epoch 256, minibatch 238/238, training error 17.205042 %  , validation error 16.920000 %
# epoch 257, minibatch 238/238, training error 16.122689 %  , validation error 15.870000 %
# epoch 258, minibatch 238/238, training error 16.070588 %  , validation error 15.730000 %
# epoch 259, minibatch 238/238, training error 15.857143 %  , validation error 15.600000 %
# epoch 260, minibatch 238/238, training error 15.691597 %  , validation error 15.580000 %
# epoch 261, minibatch 238/238, training error 15.301681 %  , validation error 15.250000 %
# epoch 262, minibatch 238/238, training error 14.238655 %  , validation error 14.580000 %
# epoch 263, minibatch 238/238, training error 13.861345 %  , validation error 14.190000 %
# epoch 264, minibatch 238/238, training error 13.783193 %  , validation error 14.130000 %
# epoch 265, minibatch 238/238, training error 14.424370 %  , validation error 14.610000 %
# epoch 266, minibatch 238/238, training error 15.530252 %  , validation error 15.400000 %
# epoch 267, minibatch 238/238, training error 15.417647 %  , validation error 15.290000 %
# epoch 268, minibatch 238/238, training error 17.189076 %  , validation error 16.850000 %
# epoch 269, minibatch 238/238, training error 13.413445 %  , validation error 13.780000 %
# epoch 270, minibatch 238/238, training error 17.786555 %  , validation error 17.510000 %
# epoch 271, minibatch 238/238, training error 13.315966 %  , validation error 13.650000 %
# epoch 272, minibatch 238/238, training error 14.746218 %  , validation error 14.780000 %
# epoch 273, minibatch 238/238, training error 13.443697 %  , validation error 13.710000 %
# epoch 274, minibatch 238/238, training error 14.102521 %  , validation error 14.250000 %
# epoch 275, minibatch 238/238, training error 13.184034 %  , validation error 13.470000 %
# epoch 276, minibatch 238/238, training error 13.152941 %  , validation error 13.510000 %
# epoch 277, minibatch 238/238, training error 15.792437 %  , validation error 15.430000 %
# epoch 278, minibatch 238/238, training error 13.117647 %  , validation error 13.370000 %
# epoch 279, minibatch 238/238, training error 13.836975 %  , validation error 13.980000 %
# epoch 280, minibatch 238/238, training error 14.370588 %
