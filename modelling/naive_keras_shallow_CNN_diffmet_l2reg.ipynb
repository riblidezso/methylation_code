# %% [markdown]
# # Very naive deep learning on the vector of surrounding bases
#
# ---
#
# ### Data
#
# Naive feature vectors. The original sequence of validation/test and train data does not overlap! ( but train data points can overlap with train data points, and test-validation can overlap with test-validation data ) This overlapping does not lead to unintentional label leakage!
#
#
#
# ### Notes
#
#
# ---

# %% [markdown]
# Instruct theano to use gpu

# %%
import os
os.environ['THEANO_FLAGS']='device=gpu'

import sys
sys.path.append('../my_modules')
from loading_utils import read_my_data

import subprocess
import time

import numpy as np
import pandas as pd

import os,subprocess
workdir='/mnt/Data1/ribli/methylation_code/modelling'
subprocess.call(['mkdir',workdir])
os.chdir(workdir)

# %% [markdown]
# ### Load data

# %%
train_id,train_x,train_y = read_my_data(
    fname='../prepare_data/diffmet_train_feat_vect.csv')
test_id,test_x,test_y = read_my_data(
    fname='../prepare_data/diffmet_test_feat_vect.csv')
# Out:
# Loading data...
# Loading data...

# %% [markdown]
# ### One-hot encode them into 2d image

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(np.concatenate([train_x.flatten(),test_x.flatten()]))

one_hot_train_x=lb.transform(train_x.flatten()).reshape((-1,1,1000,4))
one_hot_test_x=lb.transform(test_x.flatten()).reshape((-1,1,1000,4))

# %% [markdown]
# ### Build convnet

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D,MaxPooling2D
from keras.regularizers import l2

input_dim=one_hot_train_x.shape[2]
activation='relu'
loss='binary_crossentropy'
optimizer='adadelta'
init='uniform'
pool_size=(991,1)
window_size=10

model = Sequential()

#Convolution layer
model.add(Convolution2D(40,window_size,4, border_mode='valid',
                        input_shape=(1,input_dim,4),W_regularizer=l2(0.01)))
model.add(Activation(activation))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Flatten())
model.add(Dropout(0.2))

#final layer
model.add(Dense(1, activation='sigmoid'))


#compile model
model.compile(loss=loss,optimizer=optimizer,class_mode='binary')
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 670 (CNMeM is disabled, CuDNN not available)
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/theano/tensor/signal/downsample.py:5: UserWarning: downsample module has been moved to the pool module.
#   warnings.warn("downsample module has been moved to the pool module.")

# %% [markdown]
# ### Train and test model

# %%
from keras.callbacks import ModelCheckpoint,EarlyStopping
def fit_keras_model(model,train_x,train_y,test_x,test_y,validation_split=0.05):
    start=time.time()
    
    #callbacks
    best_model=ModelCheckpoint('best_model',save_best_only=True,verbose=1)
    early_stop=EarlyStopping(patience=7,verbose=1)
    
    #train it
    callb_hist=model.fit(train_x,train_y,nb_epoch = 100,
                         show_accuracy=True,verbose=1,
                        validation_split=validation_split,
                        callbacks=[best_model,early_stop])
    #predict
    model.load_weights('best_model')
    train_pred=model.predict_classes(train_x).ravel()
    test_pred=model.predict_classes(test_x).ravel()
    
    train_pred_pr=model.predict(train_x).ravel()
    test_pred_pr=model.predict(test_x).ravel()

    #check errors
    print 'train accuracy:',list((train_pred==train_y)).count(True)/float(len(train_y))
    print 'test accuracy:',list((test_pred==test_y)).count(True)/float(len(test_y))

    print 'It took:',time.time()-start    
    return train_pred,test_pred,train_pred_pr,test_pred_pr

# %%
train_pred,test_pred,train_pred_pr,test_pred_pr=fit_keras_model(
    model,one_hot_train_x,train_y,one_hot_test_x,test_y,validation_split=0.2)

print '\nprediction balance:'
print np.mean(train_pred)
print np.mean(test_pred)
# Out:
# Train on 5155 samples, validate on 1289 samples
# Epoch 1/100
# 5155/5155 [==============================] - 2s - loss: 1.0404 - acc: 0.5044 - val_loss: 0.7170 - val_acc: 0.4919
# Epoch 00000: val_loss improved from inf to 0.71696, saving model to best_model
# Epoch 2/100
# 5155/5155 [==============================] - 2s - loss: 0.8241 - acc: 0.5216 - val_loss: 0.6862 - val_acc: 0.5756
# Epoch 00001: val_loss improved from 0.71696 to 0.68618, saving model to best_model
# Epoch 3/100
# 5155/5155 [==============================] - 2s - loss: 0.7551 - acc: 0.5104 - val_loss: 0.6861 - val_acc: 0.5190
# Epoch 00002: val_loss improved from 0.68618 to 0.68615, saving model to best_model
# Epoch 4/100
# 5155/5155 [==============================] - 2s - loss: 0.7178 - acc: 0.5381 - val_loss: 0.6842 - val_acc: 0.5244
# Epoch 00003: val_loss improved from 0.68615 to 0.68423, saving model to best_model
# Epoch 5/100
# 5155/5155 [==============================] - 2s - loss: 0.7064 - acc: 0.5371 - val_loss: 0.6863 - val_acc: 0.5081
# Epoch 00004: val_loss did not improve
# Epoch 6/100
# 5155/5155 [==============================] - 2s - loss: 0.6975 - acc: 0.5439 - val_loss: 0.6861 - val_acc: 0.5089
# Epoch 00005: val_loss did not improve
# Epoch 7/100
# 5155/5155 [==============================] - 2s - loss: 0.6945 - acc: 0.5465 - val_loss: 0.7130 - val_acc: 0.4919
# Epoch 00006: val_loss did not improve
# Epoch 8/100
# 5155/5155 [==============================] - 2s - loss: 0.6917 - acc: 0.5595 - val_loss: 0.6807 - val_acc: 0.5268
# Epoch 00007: val_loss improved from 0.68423 to 0.68075, saving model to best_model
# Epoch 9/100
# 5155/5155 [==============================] - 2s - loss: 0.6922 - acc: 0.5538 - val_loss: 0.6817 - val_acc: 0.5446
# Epoch 00008: val_loss did not improve
# Epoch 10/100
# 5155/5155 [==============================] - 2s - loss: 0.6882 - acc: 0.5771 - val_loss: 0.6805 - val_acc: 0.5423
# Epoch 00009: val_loss improved from 0.68075 to 0.68055, saving model to best_model
# Epoch 11/100
# 5155/5155 [==============================] - 2s - loss: 0.6888 - acc: 0.5701 - val_loss: 0.6968 - val_acc: 0.5081
# Epoch 00010: val_loss did not improve
# Epoch 12/100
# 5155/5155 [==============================] - 2s - loss: 0.6889 - acc: 0.5763 - val_loss: 0.7069 - val_acc: 0.5081
# Epoch 00011: val_loss did not improve
# Epoch 13/100
# 5155/5155 [==============================] - 2s - loss: 0.6882 - acc: 0.5798 - val_loss: 0.6968 - val_acc: 0.4919
# Epoch 00012: val_loss did not improve
# Epoch 14/100
# 5155/5155 [==============================] - 2s - loss: 0.6901 - acc: 0.5705 - val_loss: 0.7000 - val_acc: 0.4919
# Epoch 00013: val_loss did not improve
# Epoch 15/100
# 5155/5155 [==============================] - 2s - loss: 0.6897 - acc: 0.5653 - val_loss: 0.6719 - val_acc: 0.6338
# Epoch 00014: val_loss improved from 0.68055 to 0.67189, saving model to best_model
# Epoch 16/100
# 5155/5155 [==============================] - 2s - loss: 0.6841 - acc: 0.5907 - val_loss: 0.6966 - val_acc: 0.5112
# Epoch 00015: val_loss did not improve
# Epoch 17/100
# 5155/5155 [==============================] - 2s - loss: 0.6878 - acc: 0.5742 - val_loss: 0.6835 - val_acc: 0.5066
# Epoch 00016: val_loss did not improve
# Epoch 18/100
# 5155/5155 [==============================] - 2s - loss: 0.6871 - acc: 0.5790 - val_loss: 0.6731 - val_acc: 0.5469
# Epoch 00017: val_loss did not improve
# Epoch 19/100
# 5155/5155 [==============================] - 2s - loss: 0.6800 - acc: 0.5981 - val_loss: 0.6746 - val_acc: 0.5415
# Epoch 00018: val_loss did not improve
# Epoch 20/100
# 5155/5155 [==============================] - 2s - loss: 0.6818 - acc: 0.5858 - val_loss: 0.7063 - val_acc: 0.5120
# Epoch 00019: val_loss did not improve
# Epoch 21/100
# 5155/5155 [==============================] - 2s - loss: 0.6909 - acc: 0.5759 - val_loss: 0.6662 - val_acc: 0.5896
# Epoch 00020: val_loss improved from 0.67189 to 0.66620, saving model to best_model
# Epoch 22/100
# 5155/5155 [==============================] - 2s - loss: 0.6809 - acc: 0.5961 - val_loss: 0.6619 - val_acc: 0.6191
# Epoch 00021: val_loss improved from 0.66620 to 0.66191, saving model to best_model
# Epoch 23/100
# 5155/5155 [==============================] - 2s - loss: 0.6779 - acc: 0.6039 - val_loss: 0.6590 - val_acc: 0.6315
# Epoch 00022: val_loss improved from 0.66191 to 0.65900, saving model to best_model
# Epoch 24/100
# 5155/5155 [==============================] - 2s - loss: 0.6809 - acc: 0.5940 - val_loss: 0.6962 - val_acc: 0.4965
# Epoch 00023: val_loss did not improve
# Epoch 25/100
# 5155/5155 [==============================] - 2s - loss: 0.6859 - acc: 0.5816 - val_loss: 0.6643 - val_acc: 0.5849
# Epoch 00024: val_loss did not improve
# Epoch 26/100
# 5155/5155 [==============================] - 2s - loss: 0.6786 - acc: 0.5992 - val_loss: 0.6572 - val_acc: 0.6292
# Epoch 00025: val_loss improved from 0.65900 to 0.65718, saving model to best_model
# Epoch 27/100
# 5155/5155 [==============================] - 2s - loss: 0.6778 - acc: 0.6060 - val_loss: 0.7537 - val_acc: 0.4919
# Epoch 00026: val_loss did not improve
# Epoch 28/100
# 5155/5155 [==============================] - 2s - loss: 0.6817 - acc: 0.5990 - val_loss: 0.6922 - val_acc: 0.5004
# Epoch 00027: val_loss did not improve
# Epoch 29/100
# 5155/5155 [==============================] - 2s - loss: 0.6736 - acc: 0.6177 - val_loss: 0.6573 - val_acc: 0.6036
# Epoch 00028: val_loss did not improve
# Epoch 30/100
# 5155/5155 [==============================] - 2s - loss: 0.6768 - acc: 0.6118 - val_loss: 0.6587 - val_acc: 0.5873
# Epoch 00029: val_loss did not improve
# Epoch 31/100
# 5155/5155 [==============================] - 2s - loss: 0.6863 - acc: 0.5868 - val_loss: 0.7233 - val_acc: 0.4911
# Epoch 00030: val_loss did not improve
# Epoch 32/100
# 5155/5155 [==============================] - 2s - loss: 0.6810 - acc: 0.6033 - val_loss: 0.7423 - val_acc: 0.4919
# Epoch 00031: val_loss did not improve
# Epoch 33/100
# 5155/5155 [==============================] - 2s - loss: 0.6808 - acc: 0.6087 - val_loss: 0.6513 - val_acc: 0.6431
# Epoch 00032: val_loss improved from 0.65718 to 0.65128, saving model to best_model
# Epoch 34/100
# 5155/5155 [==============================] - 2s - loss: 0.6695 - acc: 0.6198 - val_loss: 0.6540 - val_acc: 0.6043
# Epoch 00033: val_loss did not improve
# Epoch 35/100
# 5155/5155 [==============================] - 2s - loss: 0.6696 - acc: 0.6219 - val_loss: 0.6502 - val_acc: 0.6354
# Epoch 00034: val_loss improved from 0.65128 to 0.65021, saving model to best_model
# Epoch 36/100
# 5155/5155 [==============================] - 2s - loss: 0.6716 - acc: 0.6196 - val_loss: 0.6845 - val_acc: 0.5190
# Epoch 00035: val_loss did not improve
# Epoch 37/100
# 5155/5155 [==============================] - 2s - loss: 0.6771 - acc: 0.6114 - val_loss: 0.6444 - val_acc: 0.6555
# Epoch 00036: val_loss improved from 0.65021 to 0.64441, saving model to best_model
# Epoch 38/100
# 5155/5155 [==============================] - 2s - loss: 0.6696 - acc: 0.6192 - val_loss: 0.6425 - val_acc: 0.6594
# Epoch 00037: val_loss improved from 0.64441 to 0.64251, saving model to best_model
# Epoch 39/100
# 5155/5155 [==============================] - 2s - loss: 0.6670 - acc: 0.6295 - val_loss: 0.6402 - val_acc: 0.6602
# Epoch 00038: val_loss improved from 0.64251 to 0.64022, saving model to best_model
# Epoch 40/100
# 5155/5155 [==============================] - 2s - loss: 0.6688 - acc: 0.6144 - val_loss: 0.6563 - val_acc: 0.5834
# Epoch 00039: val_loss did not improve
# Epoch 41/100
# 5155/5155 [==============================] - 2s - loss: 0.6732 - acc: 0.6169 - val_loss: 0.6418 - val_acc: 0.6687
# Epoch 00040: val_loss did not improve
# Epoch 42/100
# 5155/5155 [==============================] - 2s - loss: 0.6711 - acc: 0.6144 - val_loss: 0.6684 - val_acc: 0.5539
# Epoch 00041: val_loss did not improve
# Epoch 43/100
# 5155/5155 [==============================] - 2s - loss: 0.6840 - acc: 0.5940 - val_loss: 0.6373 - val_acc: 0.6687
# Epoch 00042: val_loss improved from 0.64022 to 0.63735, saving model to best_model
# Epoch 44/100
# 5155/5155 [==============================] - 2s - loss: 0.6693 - acc: 0.6287 - val_loss: 0.6381 - val_acc: 0.6664
# Epoch 00043: val_loss did not improve
# Epoch 45/100
# 5155/5155 [==============================] - 2s - loss: 0.6659 - acc: 0.6314 - val_loss: 0.6354 - val_acc: 0.6773
# Epoch 00044: val_loss improved from 0.63735 to 0.63545, saving model to best_model
# Epoch 46/100
# 5155/5155 [==============================] - 2s - loss: 0.6659 - acc: 0.6266 - val_loss: 0.7629 - val_acc: 0.5136
# Epoch 00045: val_loss did not improve
# Epoch 47/100
# 5155/5155 [==============================] - 2s - loss: 0.6720 - acc: 0.6169 - val_loss: 0.6344 - val_acc: 0.6695
# Epoch 00046: val_loss improved from 0.63545 to 0.63442, saving model to best_model
# Epoch 48/100
# 5155/5155 [==============================] - 2s - loss: 0.6629 - acc: 0.6407 - val_loss: 0.6352 - val_acc: 0.6633
# Epoch 00047: val_loss did not improve
# Epoch 49/100
# 5155/5155 [==============================] - 2s - loss: 0.6683 - acc: 0.6264 - val_loss: 0.6516 - val_acc: 0.5989
# Epoch 00048: val_loss did not improve
# Epoch 50/100
# 5155/5155 [==============================] - 2s - loss: 0.6623 - acc: 0.6341 - val_loss: 0.6595 - val_acc: 0.5826
# Epoch 00049: val_loss did not improve
# Epoch 51/100
# 5155/5155 [==============================] - 2s - loss: 0.6704 - acc: 0.6235 - val_loss: 0.7724 - val_acc: 0.4926
# Epoch 00050: val_loss did not improve
# Epoch 52/100
# 5155/5155 [==============================] - 2s - loss: 0.6676 - acc: 0.6343 - val_loss: 0.6607 - val_acc: 0.5756
# Epoch 00051: val_loss did not improve
# Epoch 53/100
# 5155/5155 [==============================] - 2s - loss: 0.6685 - acc: 0.6320 - val_loss: 0.6580 - val_acc: 0.5795
# Epoch 00052: val_loss did not improve
# Epoch 54/100
# 5155/5155 [==============================] - 2s - loss: 0.6730 - acc: 0.6169 - val_loss: 0.6308 - val_acc: 0.6788
# Epoch 00053: val_loss improved from 0.63442 to 0.63083, saving model to best_model
# Epoch 55/100
# 5155/5155 [==============================] - 2s - loss: 0.6568 - acc: 0.6394 - val_loss: 0.6550 - val_acc: 0.5958
# Epoch 00054: val_loss did not improve
# Epoch 56/100
# 5155/5155 [==============================] - 2s - loss: 0.6597 - acc: 0.6359 - val_loss: 0.6366 - val_acc: 0.6323
# Epoch 00055: val_loss did not improve
# Epoch 57/100
# 5155/5155 [==============================] - 2s - loss: 0.6566 - acc: 0.6442 - val_loss: 0.6408 - val_acc: 0.6245
# Epoch 00056: val_loss did not improve
# Epoch 58/100
# 5155/5155 [==============================] - 2s - loss: 0.6541 - acc: 0.6572 - val_loss: 0.6310 - val_acc: 0.6501
# Epoch 00057: val_loss did not improve
# Epoch 59/100
# 5155/5155 [==============================] - 2s - loss: 0.6609 - acc: 0.6353 - val_loss: 0.6483 - val_acc: 0.6020
# Epoch 00058: val_loss did not improve
# Epoch 60/100
# 5155/5155 [==============================] - 2s - loss: 0.6699 - acc: 0.6246 - val_loss: 0.7569 - val_acc: 0.4957
# Epoch 00059: val_loss did not improve
# Epoch 61/100
# 5155/5155 [==============================] - 2s - loss: 0.6689 - acc: 0.6235 - val_loss: 0.6372 - val_acc: 0.6323
# Epoch 00060: val_loss did not improve
# Epoch 62/100
# 5155/5155 [==============================] - 2s - loss: 0.6653 - acc: 0.6365 - val_loss: 0.7068 - val_acc: 0.5120
# Epoch 00061: val_loss did not improve
# Epoch 00061: early stopping
# 6444/6444 [==============================] - 1s
# 552/552 [==============================] - 0s
# train accuracy: 0.700496585971
# test accuracy: 0.659420289855
# It took: 185.983181953
#
# prediction balance:
# 0.506517690875
# 0.576086956522

# %% [markdown]
# ### roc and auc

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.style.use('ggplot')
# %matplotlib inline

from sklearn import metrics
def plot_roc(y,probs):
    fpr, tpr, thresholds = metrics.roc_curve(y,probs)
    auc=metrics.roc_auc_score(y,probs)
    
    plt.figure(figsize=(6,6))
    plt.plot(fpr,tpr,lw=2)
    plt.plot([0,1],[0,1],lw=2)
    plt.xlim(-0.01,1.01)
    plt.ylim(-0.01,1.01)
    plt.xlabel('FP rate')
    plt.ylabel('TP rate')
    print 'auc:',auc

# %%
plot_roc(test_y,test_pred_pr)
# Out:
# auc: 0.849538461538

# %% [markdown]
# ### Kernels

# %%
conv1=model.layers[0]
weigths,bias=conv1.get_weights()

dense1=model.layers[5]
weigths2,bias2=dense1.get_weights()

# %%
idx=np.argsort(weigths2.flatten())
for w,w2 in zip(weigths[idx],weigths2[idx]):
    plt.figure(figsize=(12,3))
    plt.imshow(w[0].T,interpolation='none',aspect=0.5,cmap='Blues')
    plt.colorbar()
    plt.title('weight='+str(w2[0]))
    dump=plt.yticks([0,1,2,3],['A','C','G','T'])
# Out:
# /mnt/Data1/ribli/tools/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:516: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
