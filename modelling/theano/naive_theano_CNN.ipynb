# %% [markdown]
# # Very naive deep learning on the vector of surrounding bases
#
#
# ---
#
# ### Data
#
# Naive feature vectors. The original sequence of any data points does not overlap.
#
#
#
# ### Notes
#
#
# ---

# %% [markdown]
# Instruct theano to use gpu

# %%
import os
os.environ['THEANO_FLAGS']='floatX=float32,device=gpu'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import subprocess
import time

# %% [markdown]
# ### Load data

# %%
import pandas as pd
import numpy as np
import gc

def load_my_data(fname='/mnt/Data1/ribli/methylation_code/prepare_data/meth_feat_vect.csv'):
    """Load my data from file into np.arrays.
    
    It uses int8 for memory efficiency, and speed. Later the values will be
    used as float64 and int32, but pandas double memory usage during loading, so
    I simply can not load them like that. This way the memory usage is not double but
    1+small.
    I have to use garbage collector, because pandas read_csv leaves garbage around.
    """
    
    #load data
    print "Loading data... "
    x=pd.read_csv(fname,sep='\t',engine='c',dtype=np.int8,header=None)
    #shuffle rows
    #this is not necessary it is juts for safety now
    x=x.reindex(np.random.permutation(x.index)).reset_index(drop=True)

    y=np.array(x.iloc[:,-1])
    x=np.array(x.iloc[:,:-1])
    
    # for some reason not everything is cleaned up
    #when using the pandas read_csv
    gc.collect()
    
    return x,y


def load_data(N_train=8000,N_valid=1000,N_test=1000,length=1000):
    """Load and segment my data into random train,valid,test sets for theano."""
    x,y=load_my_data()

    #select a random subset of data
    rng = np.random.RandomState(23455) # not so random now
    perm=rng.permutation(len(x))
    train_idx=perm[:N_train]
    valid_idx=perm[N_train:N_train+N_valid]
    test_idx=perm[N_train+N_valid:N_train+N_valid+N_test]
    
    #determine the slice of data needed
    if length%2==0:
        start=500-length/2
    else:
        start=500-length/2 - 1
        
    my_train_set_x=theano.shared(np.float32(x[train_idx,start:start+length]))
    my_valid_set_x=theano.shared(np.float32(x[valid_idx,start:start+length]))
    my_test_set_x=theano.shared(np.float32(x[test_idx,start:start+length]))

    my_train_set_y=theano.shared(np.int32(y[train_idx]))
    my_valid_set_y=theano.shared(np.int32(y[valid_idx]))
    my_test_set_y=theano.shared(np.int32(y[test_idx]))

    return ((my_train_set_x,my_train_set_y),
            (my_valid_set_x,my_valid_set_y),
            (my_test_set_x,my_test_set_y))

# %% [markdown]
# ### Load modules

# %%
import sys
import timeit

import theano
import theano.tensor as T
from theano.tensor.nnet import conv
from theano.tensor.signal import downsample

import numpy
# Out:
# Using gpu device 0: GeForce GTX 670

# %%
class LogisticRegression(object):
    """Multi-class Logistic Regression Class

    The logistic regression is fully described by a weight matrix :math:`W`
    and bias vector :math:`b`. Classification is done by projecting data
    points onto a set of hyperplanes, the distance to which is used to
    determine a class membership probability.
    """

    def __init__(self, input, n_in, n_out):
        """ Initialize the parameters of the logistic regression

        :type input: theano.tensor.TensorType
        :param input: symbolic variable that describes the input of the
                      architecture (one minibatch)

        :type n_in: int
        :param n_in: number of input units, the dimension of the space in
                     which the datapoints lie

        :type n_out: int
        :param n_out: number of output units, the dimension of the space in
                      which the labels lie

        """
        # start-snippet-1
        # initialize with 0 the weights W as a matrix of shape (n_in, n_out)
        self.W = theano.shared(
            value=numpy.zeros(
                (n_in, n_out),
                dtype=theano.config.floatX
            ),
            name='W',
            borrow=True
        )
        # initialize the biases b as a vector of n_out 0s
        self.b = theano.shared(
            value=numpy.zeros(
                (n_out,),
                dtype=theano.config.floatX
            ),
            name='b',
            borrow=True
        )

        # symbolic expression for computing the matrix of class-membership
        # probabilities
        # Where:
        # W is a matrix where column-k represent the separation hyperplane for
        # class-k
        # x is a matrix where row-j  represents input training sample-j
        # b is a vector where element-k represent the free parameter of
        # hyperplane-k
        self.p_y_given_x = T.nnet.softmax(T.dot(input, self.W) + self.b)

        # symbolic description of how to compute prediction as class whose
        # probability is maximal
        self.y_pred = T.argmax(self.p_y_given_x, axis=1)
        # end-snippet-1

        # parameters of the model
        self.params = [self.W, self.b]

        # keep track of model input
        self.input = input

    def negative_log_likelihood(self, y):
        """Return the mean of the negative log-likelihood of the prediction
        of this model under a given target distribution.

        .. math::

            \frac{1}{|\mathcal{D}|} \mathcal{L} (\theta=\{W,b\}, \mathcal{D}) =
            \frac{1}{|\mathcal{D}|} \sum_{i=0}^{|\mathcal{D}|}
                \log(P(Y=y^{(i)}|x^{(i)}, W,b)) \\
            \ell (\theta=\{W,b\}, \mathcal{D})

        :type y: theano.tensor.TensorType
        :param y: corresponds to a vector that gives for each example the
                  correct label

        Note: we use the mean instead of the sum so that
              the learning rate is less dependent on the batch size
        """
        # start-snippet-2
        # y.shape[0] is (symbolically) the number of rows in y, i.e.,
        # number of examples (call it n) in the minibatch
        # T.arange(y.shape[0]) is a symbolic vector which will contain
        # [0,1,2,... n-1] T.log(self.p_y_given_x) is a matrix of
        # Log-Probabilities (call it LP) with one row per example and
        # one column per class LP[T.arange(y.shape[0]),y] is a vector
        # v containing [LP[0,y[0]], LP[1,y[1]], LP[2,y[2]], ...,
        # LP[n-1,y[n-1]]] and T.mean(LP[T.arange(y.shape[0]),y]) is
        # the mean (across minibatch examples) of the elements in v,
        # i.e., the mean log-likelihood across the minibatch.
        return -T.mean(T.log(self.p_y_given_x)[T.arange(y.shape[0]), y])
        # end-snippet-2

    def errors(self, y):
        """Return a float representing the number of errors in the minibatch
        over the total number of examples of the minibatch ; zero one
        loss over the size of the minibatch

        :type y: theano.tensor.TensorType
        :param y: corresponds to a vector that gives for each example the
                  correct label
        """

        # check if y has same dimension of y_pred
        if y.ndim != self.y_pred.ndim:
            raise TypeError(
                'y should have the same shape as self.y_pred',
                ('y', y.type, 'y_pred', self.y_pred.type)
            )
        # check if y is of the correct datatype
        if y.dtype.startswith('int'):
            # the T.neq operator returns a vector of 0s and 1s, where 1
            # represents a mistake in prediction
            return T.mean(T.neq(self.y_pred, y))
        else:
            raise NotImplementedError()

# %%
class HiddenLayer(object):
    def __init__(self, rng, input, n_in, n_out, W=None, b=None,
                 activation=T.tanh):
        """
        Typical hidden layer of a MLP: units are fully-connected and have
        sigmoidal activation function. Weight matrix W is of shape (n_in,n_out)
        and the bias vector b is of shape (n_out,).

        NOTE : The nonlinearity used here is tanh

        Hidden unit activation is given by: tanh(dot(input,W) + b)

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dmatrix
        :param input: a symbolic tensor of shape (n_examples, n_in)

        :type n_in: int
        :param n_in: dimensionality of input

        :type n_out: int
        :param n_out: number of hidden units

        :type activation: theano.Op or function
        :param activation: Non linearity to be applied in the hidden
                           layer
        """
        self.input = input
        # end-snippet-1

        # `W` is initialized with `W_values` which is uniformely sampled
        # from sqrt(-6./(n_in+n_hidden)) and sqrt(6./(n_in+n_hidden))
        # for tanh activation function
        # the output of uniform if converted using asarray to dtype
        # theano.config.floatX so that the code is runable on GPU
        # Note : optimal initialization of weights is dependent on the
        #        activation function used (among other things).
        #        For example, results presented in [Xavier10] suggest that you
        #        should use 4 times larger initial weights for sigmoid
        #        compared to tanh
        #        We have no info for other function, so we use the same as
        #        tanh.
        if W is None:
            W_values = numpy.asarray(
                rng.uniform(
                    low=-numpy.sqrt(6. / (n_in + n_out)),
                    high=numpy.sqrt(6. / (n_in + n_out)),
                    size=(n_in, n_out)
                ),
                dtype=theano.config.floatX
            )
            if activation == theano.tensor.nnet.sigmoid:
                W_values *= 4

            W = theano.shared(value=W_values, name='W', borrow=True)

        if b is None:
            b_values = numpy.zeros((n_out,), dtype=theano.config.floatX)
            b = theano.shared(value=b_values, name='b', borrow=True)

        self.W = W
        self.b = b

        lin_output = T.dot(input, self.W) + self.b
        self.output = (
            lin_output if activation is None
            else activation(lin_output)
        )
        # parameters of the model
        self.params = [self.W, self.b]

# %% [markdown]
# ### Try to modify the tutorial to work on 1-d data

# %%
class LeNetConvPoolLayer(object):
    """Pool Layer of a convolutional network """

    def __init__(self, rng, input, filter_shape, image_shape, poolsize=(2, 1)):
        """
        Allocate a LeNetConvPoolLayer with shared variable internal parameters.

        :type rng: numpy.random.RandomState
        :param rng: a random number generator used to initialize weights

        :type input: theano.tensor.dtensor4
        :param input: symbolic image tensor, of shape image_shape

        :type filter_shape: tuple or list of length 4
        :param filter_shape: (number of filters, num input feature maps,
                              filter height, filter width)

        :type image_shape: tuple or list of length 4
        :param image_shape: (batch size, num input feature maps,
                             image height, image width)

        """

        assert image_shape[1] == filter_shape[1]
        self.input = input

        # there are "num input feature maps * filter height * filter width"
        # inputs to each hidden unit
        fan_in = numpy.prod(filter_shape[1:])
        # each unit in the lower layer receives a gradient from:
        # "num output feature maps * filter height * filter width" /
        #   pooling size
        fan_out = (filter_shape[0] * numpy.prod(filter_shape[2:])/
                   numpy.prod(poolsize))
        # initialize weights with random weights
        W_bound = numpy.sqrt(6. / (fan_in + fan_out))
        self.W = theano.shared(
            numpy.asarray(
                rng.uniform(low=-W_bound, high=W_bound, size=filter_shape),
                dtype=theano.config.floatX
            ),
            borrow=True
        )

        # the bias is a 1D tensor -- one bias per output feature map
        b_values = numpy.zeros((filter_shape[0],), dtype=theano.config.floatX)
        self.b = theano.shared(value=b_values, borrow=True)

        # convolve input feature maps with filters
        conv_out = conv.conv2d(
            input=input,
            filters=self.W,
            filter_shape=filter_shape,
            image_shape=image_shape
        )

        # downsample each feature map individually, using maxpooling
        pooled_out = downsample.max_pool_2d(
            input=conv_out,
            ds=poolsize,
            ignore_border=True
        )

        # add the bias term. Since the bias is a vector (1D array), we first
        # reshape it to a tensor of shape (1, n_filters, 1, 1). Each bias will
        # thus be broadcasted across mini-batches and feature map
        # width & height
        self.output = T.tanh(pooled_out + self.b.dimshuffle('x', 0, 'x', 'x'))

        # store parameters of this layer
        self.params = [self.W, self.b]

        # keep track of model input
        self.input = input

# %%
def evaluate_lenet5(learning_rate=0.1, n_epochs=200,
                    nkerns=[20, 50], pool_size=(2,1), window_size=5,
                    batch_size=2000,
                    N_train=8000,N_valid=1000,N_test=1000,
                    n_hid_input=400,n_hid_output=500):
    """ Demonstrates lenet on MNIST dataset

    :type learning_rate: float
    :param learning_rate: learning rate used (factor for the stochastic
                          gradient)

    :type n_epochs: int
    :param n_epochs: maximal number of epochs to run the optimizer

    :type dataset: string
    :param dataset: path to the dataset used for training /testing (MNIST here)

    :type nkerns: list of ints
    :param nkerns: number of kernels on each layer
    """

    rng = numpy.random.RandomState(23455)

    #dataset
    length=((n_hid_input*pool_size[0])+window_size-1)*pool_size[0]+window_size-1
    datasets = load_data(N_train=N_train,N_valid=N_valid,N_test=N_test,length=length)

    train_set_x, train_set_y = datasets[0]
    valid_set_x, valid_set_y = datasets[1]
    test_set_x, test_set_y = datasets[2]

    # compute number of minibatches for training, validation and testing
    n_train_batches = train_set_x.get_value(borrow=True).shape[0]
    n_valid_batches = valid_set_x.get_value(borrow=True).shape[0]
    n_test_batches = test_set_x.get_value(borrow=True).shape[0]
    n_train_batches /= batch_size
    n_valid_batches /= batch_size
    n_test_batches /= batch_size

    # allocate symbolic variables for the data
    index = T.lscalar()  # index to a [mini]batch

    # start-snippet-1
    x = T.matrix('x')   # the data is presented as rasterized images
    y = T.ivector('y')  # the labels are presented as 1D vector of
                        # [int] labels

    ######################
    # BUILD ACTUAL MODEL #
    ######################
    print '... building the model'

    # Reshape matrix of rasterized images of shape (batch_size, 28 * 28)
    # to a 4D tensor, compatible with our LeNetConvPoolLayer
    # (28, 28) is the size of MNIST images.
    layer0_input = x.reshape((batch_size, 1,length,1))

    # Construct the first convolutional pooling layer:
    # filtering reduces the image size to (28-5+1 , 28-5+1) = (24, 24)
    # maxpooling reduces this further to (24/2, 24/2) = (12, 12)
    # 4D output tensor is thus of shape (batch_size, nkerns[0], 12, 12)
    layer0 = LeNetConvPoolLayer(
        rng,
        input=layer0_input,
        image_shape=(batch_size, 1, length,1),
        filter_shape=(nkerns[0], 1, window_size, 1),
        poolsize=pool_size
    )

    # Construct the second convolutional pooling layer
    # filtering reduces the image size to (12-5+1, 12-5+1) = (8, 8)
    # maxpooling reduces this further to (8/2, 8/2) = (4, 4)
    # 4D output tensor is thus of shape (batch_size, nkerns[1], 4, 4)
    layer1 = LeNetConvPoolLayer(
        rng,
        input=layer0.output,
        image_shape=(batch_size, nkerns[0], n_hid_input*pool_size[0]+window_size-1,1),
        filter_shape=(nkerns[1], nkerns[0], window_size, 1),
        poolsize=pool_size
    )

    # the HiddenLayer being fully-connected, it operates on 2D matrices of
    # shape (batch_size, num_pixels) (i.e matrix of rasterized images).
    # This will generate a matrix of shape (batch_size, nkerns[1] * 4 * 4),
    # or (500, 50 * 4 * 4) = (500, 800) with the default values.
    layer2_input = layer1.output.flatten(2)

    # construct a fully-connected sigmoidal layer
    layer2 = HiddenLayer(
        rng,
        input=layer2_input,
        n_in=nkerns[1] * 1 * n_hid_input,
        n_out=n_hid_output, 
        activation=T.tanh
    )

    # classify the values of the fully-connected sigmoidal layer
    layer3 = LogisticRegression(input=layer2.output, n_in=n_hid_output, n_out=2)

    # the cost we minimize during training is the NLL of the model
    cost = layer3.negative_log_likelihood(y)

    # create a function to compute the mistakes that are made by the model
    test_model = theano.function(
        [index],
        layer3.errors(y),
        givens={
            x: test_set_x[index * batch_size: (index + 1) * batch_size],
            y: test_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    validate_model = theano.function(
        [index],
        layer3.errors(y),
        givens={
            x: valid_set_x[index * batch_size: (index + 1) * batch_size],
            y: valid_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )
    
    check_model_on_training = theano.function(
        [index],
        layer3.errors(y),
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )

    # create a list of all model parameters to be fit by gradient descent
    params = layer3.params + layer2.params + layer1.params + layer0.params

    # create a list of gradients for all model parameters
    grads = T.grad(cost, params)

    # train_model is a function that updates the model parameters by
    # SGD Since this model has many parameters, it would be tedious to
    # manually create an update rule for each model parameter. We thus
    # create the updates list by automatically looping over all
    # (params[i], grads[i]) pairs.
    updates = [
        (param_i, param_i - learning_rate * grad_i)
        for param_i, grad_i in zip(params, grads)
    ]

    train_model = theano.function(
        [index],
        cost,
        updates=updates,
        givens={
            x: train_set_x[index * batch_size: (index + 1) * batch_size],
            y: train_set_y[index * batch_size: (index + 1) * batch_size]
        }
    )
    # end-snippet-1

    
    
    
    
    
    ###############
    # TRAIN MODEL #
    ###############
    print '... training'
    # early-stopping parameters
    patience = 10000  # look as this many examples regardless
    patience_increase = 2  # wait this much longer when a new best is
                           # found
    improvement_threshold = 0.995  # a relative improvement of this much is
                                   # considered significant
    validation_frequency = min(n_train_batches, patience / 2)
                                  # go through this many
                                  # minibatche before checking the network
                                  # on the validation set; in this case we
                                  # check every epoch

    best_validation_loss = numpy.inf
    best_iter = 0
    test_score = 0.
    start_time = timeit.default_timer()

    epoch = 0
    done_looping = False

    while (epoch < n_epochs) and (not done_looping):
        epoch = epoch + 1
        for minibatch_index in xrange(n_train_batches):

            iter = (epoch - 1) * n_train_batches + minibatch_index

            if iter % 100 == 0:
                print 'training @ iter = ', iter
            cost_ij = train_model(minibatch_index)

            if (iter + 1) % validation_frequency == 0:

                # compute zero-one loss on train set
                train_losses = [check_model_on_training(i) for i
                                     in xrange(n_train_batches)]
                this_train_loss = numpy.mean(train_losses)
                print('epoch %i, minibatch %i/%i, training error %f %%' %
                      (epoch, minibatch_index + 1, n_train_batches,
                       this_train_loss * 100.)),
                
                # compute zero-one loss on validation set
                validation_losses = [validate_model(i) for i
                                     in xrange(n_valid_batches)]
                this_validation_loss = numpy.mean(validation_losses)
                #print('epoch %i, minibatch %i/%i, validation error %f %%' %\
                # (epoch, minibatch_index + 1, n_train_batches,
                #       this_validation_loss * 100.))
                print(' , validation error %f %%' %
                       (this_validation_loss * 100.))

                # if we got the best validation score until now
                if this_validation_loss < best_validation_loss:

                    #improve patience if loss improvement is good enough
                    if this_validation_loss < best_validation_loss *  \
                       improvement_threshold:
                        patience = max(patience, iter * patience_increase)

                    # save best validation score and iteration number
                    best_validation_loss = this_validation_loss
                    best_iter = iter

                    # test it on the test set
                    test_losses = [
                        test_model(i)
                        for i in xrange(n_test_batches)
                    ]
                    test_score = numpy.mean(test_losses)
                    print(('     epoch %i, minibatch %i/%i, test error of '
                           'best model %f %%') %
                          (epoch, minibatch_index + 1, n_train_batches,
                           test_score * 100.))

            if patience <= iter:
                done_looping = True
                break

    end_time = timeit.default_timer()
    print('Optimization complete.')
    print('Best validation score of %f %% obtained at iteration %i, '
          'with test performance %f %%' %
          (best_validation_loss * 100., best_iter + 1, test_score * 100.))
    print 'The code run for %d epochs, with %f epochs/sec' % (
        epoch, 1. * epoch / (end_time - start_time))

# %%
evaluate_lenet5(learning_rate=0.05,
                batch_size=500,
                nkerns=[10, 50], #number of feature maps
                pool_size=(8,1), # max pooling reduction factor(s)
                n_hid_input=15, # number of hidden layer inputs, -> radius
                n_hid_output=50, # hidden layer number of neurons
                window_size=5, # convolution window size
                n_epochs=1000, # learning length
                N_train=50000,N_valid=5000,N_test=5000) # learning data size
# Out:
# Loading data...
# ... building the model
# ... training
# training @ iter =  0
# epoch 1, minibatch 100/100, training error 32.124000 %  , validation error 32.440000 %
#      epoch 1, minibatch 100/100, test error of best model 31.780000 %
# training @ iter =  100
# epoch 2, minibatch 100/100, training error 28.938000 %  , validation error 29.740000 %
#      epoch 2, minibatch 100/100, test error of best model 28.960000 %
# training @ iter =  200
# epoch 3, minibatch 100/100, training error 28.822000 %  , validation error 29.200000 %
#      epoch 3, minibatch 100/100, test error of best model 29.180000 %
# training @ iter =  300
# epoch 4, minibatch 100/100, training error 28.366000 %  , validation error 29.080000 %
#      epoch 4, minibatch 100/100, test error of best model 28.620000 %
# training @ iter =  400
# epoch 5, minibatch 100/100, training error 27.764000 %  , validation error 28.800000 %
#      epoch 5, minibatch 100/100, test error of best model 27.820000 %
# training @ iter =  500
# epoch 6, minibatch 100/100, training error 27.344000 %  , validation error 28.240000 %
#      epoch 6, minibatch 100/100, test error of best model 27.500000 %
# training @ iter =  600
# epoch 7, minibatch 100/100, training error 27.104000 %  , validation error 27.780000 %
#      epoch 7, minibatch 100/100, test error of best model 27.100000 %
# training @ iter =  700
# epoch 8, minibatch 100/100, training error 26.994000 %  , validation error 27.660000 %
#      epoch 8, minibatch 100/100, test error of best model 27.220000 %
# training @ iter =  800
# epoch 9, minibatch 100/100, training error 26.944000 %  , validation error 27.980000 %
# training @ iter =  900
# epoch 10, minibatch 100/100, training error 26.730000 %  , validation error 27.740000 %
# training @ iter =  1000
# epoch 11, minibatch 100/100, training error 27.096000 %  , validation error 27.680000 %
# training @ iter =  1100
# epoch 12, minibatch 100/100, training error 26.928000 %  , validation error 27.680000 %
# training @ iter =  1200
# epoch 13, minibatch 100/100, training error 27.236000 %  , validation error 28.040000 %
# training @ iter =  1300
# epoch 14, minibatch 100/100, training error 27.928000 %  , validation error 28.500000 %
# training @ iter =  1400
# epoch 15, minibatch 100/100, training error 27.360000 %  , validation error 28.220000 %
# training @ iter =  1500
# epoch 16, minibatch 100/100, training error 26.918000 %  , validation error 27.960000 %
# training @ iter =  1600
# epoch 17, minibatch 100/100, training error 26.550000 %  , validation error 27.400000 %
#      epoch 17, minibatch 100/100, test error of best model 27.400000 %
# training @ iter =  1700
# epoch 18, minibatch 100/100, training error 26.246000 %  , validation error 27.040000 %
#      epoch 18, minibatch 100/100, test error of best model 27.120000 %
# training @ iter =  1800
# epoch 19, minibatch 100/100, training error 25.978000 %  , validation error 26.720000 %
#      epoch 19, minibatch 100/100, test error of best model 26.820000 %
# training @ iter =  1900
# epoch 20, minibatch 100/100, training error 25.650000 %  , validation error 26.440000 %
#      epoch 20, minibatch 100/100, test error of best model 26.460000 %
# training @ iter =  2000
# epoch 21, minibatch 100/100, training error 25.388000 %  , validation error 26.120000 %
#      epoch 21, minibatch 100/100, test error of best model 26.160000 %
# training @ iter =  2100
# epoch 22, minibatch 100/100, training error 25.220000 %  , validation error 25.940000 %
#      epoch 22, minibatch 100/100, test error of best model 25.940000 %
# training @ iter =  2200
# epoch 23, minibatch 100/100, training error 25.112000 %  , validation error 25.800000 %
#      epoch 23, minibatch 100/100, test error of best model 26.000000 %
# training @ iter =  2300
# epoch 24, minibatch 100/100, training error 24.994000 %  , validation error 25.740000 %
#      epoch 24, minibatch 100/100, test error of best model 25.820000 %
# training @ iter =  2400
# epoch 25, minibatch 100/100, training error 24.930000 %  , validation error 25.560000 %
#      epoch 25, minibatch 100/100, test error of best model 25.640000 %
# training @ iter =  2500
# epoch 26, minibatch 100/100, training error 24.878000 %  , validation error 25.480000 %
#      epoch 26, minibatch 100/100, test error of best model 25.540000 %
# training @ iter =  2600
# epoch 27, minibatch 100/100, training error 24.832000 %  , validation error 25.420000 %
#      epoch 27, minibatch 100/100, test error of best model 25.460000 %
# training @ iter =  2700
# epoch 28, minibatch 100/100, training error 24.776000 %  , validation error 25.460000 %
# training @ iter =  2800
# epoch 29, minibatch 100/100, training error 24.728000 %  , validation error 25.460000 %
# training @ iter =  2900
# epoch 30, minibatch 100/100, training error 24.674000 %  , validation error 25.340000 %
#      epoch 30, minibatch 100/100, test error of best model 25.380000 %
# training @ iter =  3000
# epoch 31, minibatch 100/100, training error 24.622000 %  , validation error 25.320000 %
#      epoch 31, minibatch 100/100, test error of best model 25.360000 %
# training @ iter =  3100
# epoch 32, minibatch 100/100, training error 24.636000 %  , validation error 25.360000 %
# training @ iter =  3200
# epoch 33, minibatch 100/100, training error 24.610000 %  , validation error 25.380000 %
# training @ iter =  3300
# epoch 34, minibatch 100/100, training error 24.578000 %  , validation error 25.480000 %
# training @ iter =  3400
# epoch 35, minibatch 100/100, training error 24.574000 %  , validation error 25.520000 %
# training @ iter =  3500
# epoch 36, minibatch 100/100, training error 24.544000 %  , validation error 25.540000 %
# training @ iter =  3600
# epoch 37, minibatch 100/100, training error 24.544000 %  , validation error 25.560000 %
# training @ iter =  3700
# epoch 38, minibatch 100/100, training error 24.544000 %  , validation error 25.720000 %
# training @ iter =  3800
# epoch 39, minibatch 100/100, training error 24.542000 %  , validation error 25.720000 %
# training @ iter =  3900
# epoch 40, minibatch 100/100, training error 24.606000 %  , validation error 25.680000 %
# training @ iter =  4000
# epoch 41, minibatch 100/100, training error 24.634000 %  , validation error 25.840000 %
# training @ iter =  4100
# epoch 42, minibatch 100/100, training error 24.674000 %  , validation error 25.920000 %
# training @ iter =  4200
# epoch 43, minibatch 100/100, training error 24.694000 %  , validation error 25.880000 %
# training @ iter =  4300
# epoch 44, minibatch 100/100, training error 24.690000 %  , validation error 25.860000 %
# training @ iter =  4400
# epoch 45, minibatch 100/100, training error 24.676000 %  , validation error 25.920000 %
# training @ iter =  4500
# epoch 46, minibatch 100/100, training error 24.650000 %  , validation error 25.900000 %
# training @ iter =  4600
# epoch 47, minibatch 100/100, training error 24.622000 %  , validation error 25.840000 %
# training @ iter =  4700
# epoch 48, minibatch 100/100, training error 24.662000 %  , validation error 25.960000 %
# training @ iter =  4800
# epoch 49, minibatch 100/100, training error 24.640000 %  , validation error 25.940000 %
# training @ iter =  4900
# epoch 50, minibatch 100/100, training error 24.678000 %  , validation error 25.960000 %
# training @ iter =  5000
# epoch 51, minibatch 100/100, training error 24.684000 %  , validation error 26.040000 %
# training @ iter =  5100
# epoch 52, minibatch 100/100, training error 24.680000 %  , validation error 26.100000 %
# training @ iter =  5200
# epoch 53, minibatch 100/100, training error 24.698000 %  , validation error 26.120000 %
# training @ iter =  5300
# epoch 54, minibatch 100/100, training error 24.728000 %  , validation error 26.260000 %
# training @ iter =  5400
# epoch 55, minibatch 100/100, training error 24.688000 %  , validation error 26.280000 %
# training @ iter =  5500
# epoch 56, minibatch 100/100, training error 24.638000 %  , validation error 26.200000 %
# training @ iter =  5600
# epoch 57, minibatch 100/100, training error 24.654000 %  , validation error 26.320000 %
# training @ iter =  5700
# epoch 58, minibatch 100/100, training error 24.670000 %  , validation error 26.320000 %
# training @ iter =  5800
# epoch 59, minibatch 100/100, training error 24.644000 %  , validation error 26.320000 %
# training @ iter =  5900
# epoch 60, minibatch 100/100, training error 24.628000 %  , validation error 26.360000 %
# training @ iter =  6000
# epoch 61, minibatch 100/100, training error 24.584000 %  , validation error 26.440000 %
# training @ iter =  6100
# epoch 62, minibatch 100/100, training error 24.560000 %  , validation error 26.420000 %
# training @ iter =  6200
# epoch 63, minibatch 100/100, training error 24.552000 %  , validation error 26.380000 %
# training @ iter =  6300
# epoch 64, minibatch 100/100, training error 24.596000 %  , validation error 26.440000 %
# training @ iter =  6400
# epoch 65, minibatch 100/100, training error 24.578000 %  , validation error 26.480000 %
# training @ iter =  6500
# epoch 66, minibatch 100/100, training error 24.502000 %  , validation error 26.360000 %
# training @ iter =  6600
# epoch 67, minibatch 100/100, training error 24.458000 %  , validation error 26.360000 %
# training @ iter =  6700
# epoch 68, minibatch 100/100, training error 24.496000 %  , validation error 26.360000 %
# training @ iter =  6800
# epoch 69, minibatch 100/100, training error 24.440000 %  , validation error 26.360000 %
# training @ iter =  6900
# epoch 70, minibatch 100/100, training error 24.372000 %  , validation error 26.400000 %
# training @ iter =  7000
# epoch 71, minibatch 100/100, training error 24.402000 %  , validation error 26.420000 %
# training @ iter =  7100
# epoch 72, minibatch 100/100, training error 24.314000 %  , validation error 26.320000 %
# training @ iter =  7200
# epoch 73, minibatch 100/100, training error 24.266000 %  , validation error 26.260000 %
# training @ iter =  7300
# epoch 74, minibatch 100/100, training error 24.222000 %  , validation error 26.200000 %
# training @ iter =  7400
# epoch 75, minibatch 100/100, training error 24.226000 %  , validation error 26.200000 %
# training @ iter =  7500
# epoch 76, minibatch 100/100, training error 24.144000 %  , validation error 26.160000 %
# training @ iter =  7600
# epoch 77, minibatch 100/100, training error 24.094000 %  , validation error 26.140000 %
# training @ iter =  7700
# epoch 78, minibatch 100/100, training error 23.962000 %  , validation error 26.080000 %
# training @ iter =  7800
# epoch 79, minibatch 100/100, training error 24.112000 %  , validation error 26.160000 %
# training @ iter =  7900
# epoch 80, minibatch 100/100, training error 24.002000 %  , validation error 26.180000 %
# training @ iter =  8000
# epoch 81, minibatch 100/100, training error 23.982000 %  , validation error 26.160000 %
# training @ iter =  8100
# epoch 82, minibatch 100/100, training error 23.794000 %  , validation error 26.100000 %
# training @ iter =  8200
# epoch 83, minibatch 100/100, training error 23.418000 %  , validation error 25.920000 %
# training @ iter =  8300
# epoch 84, minibatch 100/100, training error 22.874000 %  , validation error 25.560000 %
# training @ iter =  8400
# epoch 85, minibatch 100/100, training error 22.218000 %  , validation error 24.800000 %
#      epoch 85, minibatch 100/100, test error of best model 24.540000 %
# training @ iter =  8500
# epoch 86, minibatch 100/100, training error 23.752000 %  , validation error 26.040000 %
# training @ iter =  8600
# epoch 87, minibatch 100/100, training error 19.506000 %  , validation error 22.360000 %
#      epoch 87, minibatch 100/100, test error of best model 21.540000 %
# training @ iter =  8700
# epoch 88, minibatch 100/100, training error 19.140000 %  , validation error 21.980000 %
#      epoch 88, minibatch 100/100, test error of best model 21.220000 %
# training @ iter =  8800
# epoch 89, minibatch 100/100, training error 18.972000 %  , validation error 22.020000 %
# training @ iter =  8900
# epoch 90, minibatch 100/100, training error 20.320000 %  , validation error 23.360000 %
# training @ iter =  9000
# epoch 91, minibatch 100/100, training error 19.250000 %  , validation error 22.320000 %
# training @ iter =  9100
# epoch 92, minibatch 100/100, training error 19.090000 %  , validation error 22.060000 %
# training @ iter =  9200
# epoch 93, minibatch 100/100, training error 18.814000 %  , validation error 22.060000 %
# training @ iter =  9300
# epoch 94, minibatch 100/100, training error 21.756000 %  , validation error 24.880000 %
# training @ iter =  9400
# epoch 95, minibatch 100/100, training error 21.032000 %  , validation error 23.960000 %
# training @ iter =  9500
# epoch 96, minibatch 100/100, training error 20.956000 %  , validation error 23.960000 %
# training @ iter =  9600
# epoch 97, minibatch 100/100, training error 21.180000 %  , validation error 24.220000 %
# training @ iter =  9700
# epoch 98, minibatch 100/100, training error 21.768000 %  , validation error 24.880000 %
# training @ iter =  9800
# epoch 99, minibatch 100/100, training error 21.122000 %  , validation error 24.380000 %
# training @ iter =  9900
# epoch 100, minibatch 100/100, training error 20.266000 %  , validation error 23.520000 %
# training @ iter =  10000
# epoch 101, minibatch 100/100, training error 21.930000 %  , validation error 25.000000 %
# training @ iter =  10100
# epoch 102, minibatch 100/100, training error 19.730000 %  , validation error 23.400000 %
# training @ iter =  10200
# epoch 103, minibatch 100/100, training error 19.890000 %  , validation error 23.540000 %
# training @ iter =  10300
# epoch 104, minibatch 100/100, training error 20.144000 %  , validation error 23.820000 %
# training @ iter =  10400
# epoch 105, minibatch 100/100, training error 18.406000 %  , validation error 22.660000 %
# training @ iter =  10500
# epoch 106, minibatch 100/100, training error 20.468000 %  , validation error 24.100000 %
# training @ iter =  10600
# epoch 107, minibatch 100/100, training error 20.864000 %  , validation error 24.280000 %
# training @ iter =  10700
# epoch 108, minibatch 100/100, training error 20.562000 %  , validation error 24.140000 %
# training @ iter =  10800
# epoch 109, minibatch 100/100, training error 19.740000 %  , validation error 23.640000 %
# training @ iter =  10900
# epoch 110, minibatch 100/100, training error 17.672000 %  , validation error 21.780000 %
#      epoch 110, minibatch 100/100, test error of best model 20.400000 %
# training @ iter =  11000
# epoch 111, minibatch 100/100, training error 19.284000 %  , validation error 23.460000 %
# training @ iter =  11100
# epoch 112, minibatch 100/100, training error 17.728000 %  , validation error 21.980000 %
# training @ iter =  11200
# epoch 113, minibatch 100/100, training error 17.534000 %  , validation error 21.840000 %
# training @ iter =  11300
# epoch 114, minibatch 100/100, training error 18.246000 %  , validation error 22.520000 %
# training @ iter =  11400
# epoch 115, minibatch 100/100, training error 17.534000 %  , validation error 22.060000 %
# training @ iter =  11500
# epoch 116, minibatch 100/100, training error 17.388000 %  , validation error 21.940000 %
# training @ iter =  11600
# epoch 117, minibatch 100/100, training error 17.366000 %  , validation error 21.880000 %
# training @ iter =  11700
# epoch 118, minibatch 100/100, training error 17.742000 %  , validation error 21.980000 %
# training @ iter =  11800
# epoch 119, minibatch 100/100, training error 19.028000 %  , validation error 23.460000 %
# training @ iter =  11900
# epoch 120, minibatch 100/100, training error 19.440000 %  , validation error 24.020000 %
# training @ iter =  12000
# epoch 121, minibatch 100/100, training error 17.918000 %  , validation error 22.660000 %
# training @ iter =  12100
# epoch 122, minibatch 100/100, training error 17.160000 %  , validation error 21.880000 %
# training @ iter =  12200
# epoch 123, minibatch 100/100, training error 17.324000 %  , validation error 22.200000 %
# training @ iter =  12300
# epoch 124, minibatch 100/100, training error 17.198000 %  , validation error 22.080000 %
# training @ iter =  12400
# epoch 125, minibatch 100/100, training error 16.920000 %  , validation error 21.940000 %
# training @ iter =  12500
# epoch 126, minibatch 100/100, training error 16.982000 %  , validation error 22.040000 %
# training @ iter =  12600
# epoch 127, minibatch 100/100, training error 17.576000 %  , validation error 22.580000 %
# training @ iter =  12700
# epoch 128, minibatch 100/100, training error 16.968000 %  , validation error 22.040000 %
# training @ iter =  12800
# epoch 129, minibatch 100/100, training error 16.866000 %  , validation error 21.980000 %
# training @ iter =  12900
# epoch 130, minibatch 100/100, training error 20.488000 %  , validation error 24.800000 %
# training @ iter =  13000
# epoch 131, minibatch 100/100, training error 16.940000 %  , validation error 22.240000 %
# training @ iter =  13100
# epoch 132, minibatch 100/100, training error 16.946000 %  , validation error 22.240000 %
# training @ iter =  13200
# epoch 133, minibatch 100/100, training error 16.906000 %  , validation error 22.280000 %
# training @ iter =  13300
# epoch 134, minibatch 100/100, training error 16.558000 %  , validation error 22.080000 %
# training @ iter =  13400
# epoch 135, minibatch 100/100, training error 16.488000 %  , validation error 22.080000 %
# training @ iter =  13500
# epoch 136, minibatch 100/100, training error 16.812000 %  , validation error 22.180000 %
# training @ iter =  13600
# epoch 137, minibatch 100/100, training error 16.800000 %  , validation error 22.400000 %
# training @ iter =  13700
# epoch 138, minibatch 100/100, training error 16.466000 %  , validation error 22.260000 %
# training @ iter =  13800
# epoch 139, minibatch 100/100, training error 16.216000 %  , validation error 21.960000 %
# training @ iter =  13900
# epoch 140, minibatch 100/100, training error 16.702000 %  , validation error 22.240000 %
# training @ iter =  14000
# epoch 141, minibatch 100/100, training error 16.576000 %  , validation error 22.080000 %
# training @ iter =  14100
# epoch 142, minibatch 100/100, training error 16.652000 %  , validation error 22.400000 %
# training @ iter =  14200
# epoch 143, minibatch 100/100, training error 16.544000 %  , validation error 22.460000 %
# training @ iter =  14300
# epoch 144, minibatch 100/100, training error 16.566000 %  , validation error 22.540000 %
# training @ iter =  14400
# epoch 145, minibatch 100/100, training error 16.808000 %  , validation error 22.740000 %
# training @ iter =  14500
# epoch 146, minibatch 100/100, training error 15.648000 %  , validation error 21.800000 %
# training @ iter =  14600
# epoch 147, minibatch 100/100, training error 16.356000 %  , validation error 22.420000 %
# training @ iter =  14700
# epoch 148, minibatch 100/100, training error 19.414000 %  , validation error 24.700000 %
# training @ iter =  14800
# epoch 149, minibatch 100/100, training error 15.620000 %  , validation error 22.120000 %
# training @ iter =  14900
# epoch 150, minibatch 100/100, training error 16.772000 %  , validation error 23.380000 %
# training @ iter =  15000
# epoch 151, minibatch 100/100, training error 16.344000 %  , validation error 23.160000 %
# training @ iter =  15100
# epoch 152, minibatch 100/100, training error 16.232000 %  , validation error 23.060000 %
# training @ iter =  15200
# epoch 153, minibatch 100/100, training error 15.402000 %  , validation error 22.200000 %
# training @ iter =  15300
# epoch 154, minibatch 100/100, training error 15.498000 %  , validation error 22.440000 %
# training @ iter =  15400
# epoch 155, minibatch 100/100, training error 19.172000 %  , validation error 24.820000 %
# training @ iter =  15500
# epoch 156, minibatch 100/100, training error 15.298000 %  , validation error 22.300000 %
# training @ iter =  15600
# epoch 157, minibatch 100/100, training error 15.146000 %  , validation error 22.500000 %
# training @ iter =  15700
# epoch 158, minibatch 100/100, training error 15.496000 %  , validation error 22.880000 %
# training @ iter =  15800
# epoch 159, minibatch 100/100, training error 15.096000 %  , validation error 22.480000 %
# training @ iter =  15900
# epoch 160, minibatch 100/100, training error 15.220000 %  , validation error 22.820000 %
# training @ iter =  16000
# epoch 161, minibatch 100/100, training error 15.318000 %  , validation error 22.780000 %
# training @ iter =  16100
# epoch 162, minibatch 100/100, training error 15.536000 %  , validation error 23.140000 %
# training @ iter =  16200
# epoch 163, minibatch 100/100, training error 15.562000 %  , validation error 23.220000 %
# training @ iter =  16300
# epoch 164, minibatch 100/100, training error 15.404000 %  , validation error 23.560000 %
# training @ iter =  16400
# epoch 165, minibatch 100/100, training error 14.794000 %  , validation error 23.160000 %
# training @ iter =  16500
# epoch 166, minibatch 100/100, training error 14.480000 %  , validation error 22.860000 %
# training @ iter =  16600
# epoch 167, minibatch 100/100, training error 14.522000 %  , validation error 23.000000 %
# training @ iter =  16700
# epoch 168, minibatch 100/100, training error 14.336000 %  , validation error 22.660000 %
# training @ iter =  16800
# epoch 169, minibatch 100/100, training error 14.518000 %  , validation error 22.760000 %
# training @ iter =  16900
# epoch 170, minibatch 100/100, training error 13.976000 %  , validation error 22.800000 %
# training @ iter =  17000
# epoch 171, minibatch 100/100, training error 17.884000 %  , validation error 25.140000 %
# training @ iter =  17100
# epoch 172, minibatch 100/100, training error 13.880000 %  , validation error 22.660000 %
# training @ iter =  17200
# epoch 173, minibatch 100/100, training error 14.504000 %  , validation error 23.660000 %
# training @ iter =  17300
# epoch 174, minibatch 100/100, training error 13.922000 %  , validation error 22.660000 %
# training @ iter =  17400
# epoch 175, minibatch 100/100, training error 14.194000 %  , validation error 23.720000 %
# training @ iter =  17500
# epoch 176, minibatch 100/100, training error 13.852000 %  , validation error 23.260000 %
# training @ iter =  17600
# epoch 177, minibatch 100/100, training error 13.912000 %  , validation error 22.980000 %
# training @ iter =  17700
# epoch 178, minibatch 100/100, training error 13.400000 %  , validation error 23.100000 %
# training @ iter =  17800
# epoch 179, minibatch 100/100, training error 13.634000 %  , validation error 23.640000 %
# training @ iter =  17900
# epoch 180, minibatch 100/100, training error 13.894000 %  , validation error 23.220000 %
# training @ iter =  18000
# epoch 181, minibatch 100/100, training error 12.878000 %  , validation error 23.100000 %
# training @ iter =  18100
# epoch 182, minibatch 100/100, training error 12.970000 %  , validation error 23.020000 %
# training @ iter =  18200
# epoch 183, minibatch 100/100, training error 13.684000 %  , validation error 23.500000 %
# training @ iter =  18300
# epoch 184, minibatch 100/100, training error 13.600000 %  , validation error 23.600000 %
# training @ iter =  18400
# epoch 185, minibatch 100/100, training error 13.516000 %  , validation error 23.700000 %
# training @ iter =  18500
# epoch 186, minibatch 100/100, training error 12.796000 %  , validation error 23.760000 %
# training @ iter =  18600
# epoch 187, minibatch 100/100, training error 12.438000 %  , validation error 23.280000 %
# training @ iter =  18700
# epoch 188, minibatch 100/100, training error 12.338000 %  , validation error 23.200000 %
# training @ iter =  18800
# epoch 189, minibatch 100/100, training error 13.218000 %  , validation error 24.060000 %
# training @ iter =  18900
# epoch 190, minibatch 100/100, training error 13.102000 %  , validation error 24.040000 %
# training @ iter =  19000
# epoch 191, minibatch 100/100, training error 13.162000 %  , validation error 23.960000 %
# training @ iter =  19100
# epoch 192, minibatch 100/100, training error 13.284000 %  , validation error 24.180000 %
# training @ iter =  19200
# epoch 193, minibatch 100/100, training error 13.308000 %  , validation error 25.480000 %
# training @ iter =  19300
# epoch 194, minibatch 100/100, training error 12.482000 %  , validation error 24.540000 %
# training @ iter =  19400
# epoch 195, minibatch 100/100, training error 11.858000 %  , validation error 24.200000 %
# training @ iter =  19500
# epoch 196, minibatch 100/100, training error 12.718000 %  , validation error 24.600000 %
# training @ iter =  19600
# epoch 197, minibatch 100/100, training error 12.366000 %  , validation error 24.260000 %
# training @ iter =  19700
# epoch 198, minibatch 100/100, training error 16.948000 %  , validation error 25.880000 %
# training @ iter =  19800
# epoch 199, minibatch 100/100, training error 12.770000 %  , validation error 25.980000 %
# training @ iter =  19900
# epoch 200, minibatch 100/100, training error 12.704000 %  , validation error 25.800000 %
# training @ iter =  20000
# epoch 201, minibatch 100/100, training error 12.256000 %  , validation error 24.620000 %
# training @ iter =  20100
# epoch 202, minibatch 100/100, training error 12.296000 %  , validation error 25.680000 %
# training @ iter =  20200
# epoch 203, minibatch 100/100, training error 11.056000 %  , validation error 24.400000 %
# training @ iter =  20300
# epoch 204, minibatch 100/100, training error 12.000000 %  , validation error 24.880000 %
# training @ iter =  20400
# epoch 205, minibatch 100/100, training error 11.262000 %  , validation error 25.180000 %
# training @ iter =  20500
# epoch 206, minibatch 100/100, training error 15.670000 %  , validation error 25.920000 %
# training @ iter =  20600
# epoch 207, minibatch 100/100, training error 10.700000 %  , validation error 24.620000 %
# training @ iter =  20700
# epoch 208, minibatch 100/100, training error 11.418000 %  , validation error 26.240000 %
# training @ iter =  20800
# epoch 209, minibatch 100/100, training error 11.332000 %  , validation error 25.100000 %
# training @ iter =  20900
# epoch 210, minibatch 100/100, training error 11.032000 %  , validation error 26.020000 %
# training @ iter =  21000
# epoch 211, minibatch 100/100, training error 11.756000 %  , validation error 25.420000 %
# training @ iter =  21100
# epoch 212, minibatch 100/100, training error 11.742000 %  , validation error 25.300000 %
# training @ iter =  21200
# epoch 213, minibatch 100/100, training error 11.634000 %  , validation error 25.460000 %
# training @ iter =  21300
# epoch 214, minibatch 100/100, training error 10.640000 %  , validation error 26.400000 %
# training @ iter =  21400
# epoch 215, minibatch 100/100, training error 10.658000 %  , validation error 26.640000 %
# training @ iter =  21500
# epoch 216, minibatch 100/100, training error 11.716000 %  , validation error 25.680000 %
# training @ iter =  21600
# epoch 217, minibatch 100/100, training error 9.790000 %  , validation error 25.600000 %
# training @ iter =  21700
# epoch 218, minibatch 100/100, training error 14.264000 %  , validation error 26.300000 %
# training @ iter =  21800
# epoch 219, minibatch 100/100, training error 10.568000 %  , validation error 25.380000 %
# training @ iter =  21900
# Optimization complete.
# Best validation score of 21.780000 % obtained at iteration 11000, with test performance 20.400000 %
# The code run for 220 epochs, with 0.034478 epochs/sec
